# %%
import random

import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

from sklearn.metrics import classification_report, roc_auc_score
from sklearn.metrics import roc_curve, auc


import uproot 
import awkward as ak
import pickle

# %%
file = "/home/dejavu/Projects/qgcal/data/dijet_sample_newBDT_flatten_data.npy"
all_jets = np.load(file)
all_jets[:, 0] = all_jets[:, 0]/1e3

# %%
all_jets.shape # Flatten events, need to reshape to split 
# leading, subleading
# forward, central
# Out:
# (26953840, 9)

# %%
all_jets = np.reshape(all_jets, (len(all_jets)//2,2,9))

# %%
all_jets.shape
# Out:
# (13476920, 2, 9)

# %%
branch_names = ["jet_pt", "jet_eta", "jet_nTracks", "jet_trackWidth", "jet_trackC1", "jet_trackBDT", "jet_PartonTruthLabelID", "total_weight", "newBDTScore"]

# %% [markdown]
# # Split Jets

# %%
label_pt = ["LeadingJet", "SubJet"]
label_eta = ["Forward", "Central"]
label_type = ["Gluon", "Quark", "C_Quark", "B_Quark", "Data", "Other"]
label_var = ["pt", "eta", "ntrk", "width", "c1", "bdt", "newBDT"]
label_pt_bin = [500, 600, 800, 1000, 1200, 1500, 2000]

# %%
def split_pt_eta_jet(jets):
    # divide jets into 4 regions 
    forward_idx = np.argmax(np.abs(jets[:,:,1]), axis=1) # compare abs eta of jets inside events
    central_idx = -1*forward_idx+1

    leading_forward_idx = forward_idx == 0 # leading forward 
    subleading_forward_idx = forward_idx == 1 # subleading forward 

    leading_central_idx = central_idx == 0 # leading central 
    subleading_central_idx = central_idx == 1 # subleading central 

    return [jets[leading_forward_idx, 0, :], jets[leading_central_idx, 0, :],  
            jets[subleading_forward_idx, 1, :], jets[subleading_central_idx, 1, :]]

def split_jet_type(jets):
    gluon_idx = np.where(jets[:,6]==21)[0]
    light_quark_idx = np.where((jets[:,6]==1) | (jets[:,6]==2)| (jets[:,6]==3))[0]
    c_quark_idx = np.where(jets[:,6]==4)[0]
    b_quark_idx = np.where(jets[:,6]==5)[0]
    data_idx = np.where(jets[:,6]==-9999)[0]
    others_idx = np.where(jets[:,6]==-1)[0]

    gluon = jets[gluon_idx]
    quark = jets[light_quark_idx]
    c_quark = jets[c_quark_idx]
    b_quark = jets[b_quark_idx]
    data = jets[data_idx]
    others = jets[others_idx]

    return [gluon, quark, c_quark, b_quark, data, others]

def split_jet_pt(jets):
    splited_jet_pt = {}
    for i, pt_start in enumerate(label_pt_bin[:-1]):
        pt_selected_idx = np.where((jets[:,0] >= pt_start) & (jets[:,0] < label_pt_bin[i+1]))[0]
        splited_jet_pt[pt_start] = jets[pt_selected_idx]

    return splited_jet_pt

# %%
HistMap = {}
###### define functions
def GetHistBin(histname):
	if 'pt' in histname:
		return 60,0,2000
	elif 'eta' in histname:
		return 50,-2.5,2.5
	elif 'ntrk' in histname:
		return 60,0,60
	elif 'bdt' in histname:
		return 60,-0.8,0.7
	elif 'width' in histname:
		return 60,0.,0.4
	elif 'c1' in histname:
		return 60,0.,0.4
	elif 'newBDT' in histname:
		return 60,-0.8,0.7

def FillTH1F(histname, var, w):
    if 'Data' in histname:
        w = np.ones(len(var))
    if histname in HistMap:
        HistMap[histname][0].append(var)
        HistMap[histname][1].append(w)
    else:
        HistMap[histname] = [[],[]] #The first list is for the data, the second for the weights
        HistMap[histname] = [[],[]]
        HistMap[histname][0].append(var)
        HistMap[histname][1].append(w)

def FillHisto(prefix, jetlist):
	for i in range(6):
		FillTH1F(prefix+"_"+label_var[i], jetlist[:,i], jetlist[:,7])

	FillTH1F(prefix+"_"+label_var[6], jetlist[:,8], jetlist[:,7])

# %%
all_jets[0]
# Out:
# array([[ 6.09158937e+02,  1.06175935e+00,  2.30000000e+01,
#          6.13516457e-02,  2.61259615e-01,  1.01512097e-01,
#         -9.99900000e+03,  1.00000000e+00,  1.18058348e-01],
#        [ 5.66184000e+02, -3.90782118e-01,  1.40000000e+01,
#          5.92113920e-02,  2.05691591e-01, -1.14423379e-01,
#         -9.99900000e+03,  1.00000000e+00, -1.14457757e-02]])

# %%
splited_pt_eta_jets = split_pt_eta_jet(all_jets)
label_pt_eta = [label1_pt + "_" + label2_eta for label1_pt in label_pt for label2_eta in label_eta]

n_jets = 0
for i, splited_pt_eta_jet in enumerate(splited_pt_eta_jets):
    n_jets += len(splited_pt_eta_jet)

    splited_pt_eta_jets_types = split_jet_type(splited_pt_eta_jet)

    for j, jet_type in enumerate(splited_pt_eta_jets_types):
        if jet_type.shape[0] == 0:
            continue 

        splited_jet_pt_bins = split_jet_pt(jet_type)

        for k, splited_jet_pt_bin in splited_jet_pt_bins.items():
            prefix = str(k) + "_" + label_pt_eta[i] + "_" + label_type[j]
            FillHisto(prefix, splited_jet_pt_bin)

assert n_jets == len(all_jets)*2 # Check if jets are splited correctly

# %%
HistMap
# Out:
# {'500_LeadingJet_Forward_Data_pt': [[array([507.30325   , 584.026125  , 563.7410625 , ..., 528.2225    ,
#           555.133875  , 500.07490625])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '500_LeadingJet_Forward_Data_eta': [[array([ 0.71226513, -0.38155711,  1.41804993, ..., -1.60686862,
#            1.05504882, -0.83009017])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '500_LeadingJet_Forward_Data_ntrk': [[array([13., 24., 17., ..., 26., 14., 20.])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '500_LeadingJet_Forward_Data_width': [[array([0.02981496, 0.12542112, 0.02517764, ..., 0.0187413 , 0.01895971,
#           0.01500422])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '500_LeadingJet_Forward_Data_c1': [[array([0.17971382, 0.27901891, 0.19649383, ..., 0.10864899, 0.16082266,
#           0.16572972])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '500_LeadingJet_Forward_Data_bdt': [[array([-0.12203559,  0.08166298,  0.01176638, ...,  0.23523769,
#           -0.16798499,  0.08679799])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '500_LeadingJet_Forward_Data_newBDT': [[array([-0.10362693,  0.17465639,  0.03143266, ..., -0.05899032,
#           -0.20571219,  0.08658036])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '600_LeadingJet_Forward_Data_pt': [[array([609.1589375, 642.42775  , 713.278625 , ..., 602.467625 ,
#           680.607125 , 656.1579375])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '600_LeadingJet_Forward_Data_eta': [[array([ 1.06175935, -0.58905727,  1.27006471, ...,  0.66891629,
#            1.82277143,  1.41666603])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '600_LeadingJet_Forward_Data_ntrk': [[array([23., 25., 14., ..., 17., 12., 11.])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '600_LeadingJet_Forward_Data_width': [[array([0.06135165, 0.07749961, 0.03462316, ..., 0.02632023, 0.01191714,
#           0.01060061])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '600_LeadingJet_Forward_Data_c1': [[array([0.26125962, 0.28877258, 0.12718233, ..., 0.20527568, 0.13307461,
#           0.15154773])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '600_LeadingJet_Forward_Data_bdt': [[array([ 0.1015121 ,  0.19669038, -0.22002061, ...,  0.04831336,
#           -0.36762223, -0.41157776])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '600_LeadingJet_Forward_Data_newBDT': [[array([ 0.11805835,  0.15428262, -0.2785392 , ...,  0.08904623,
#           -0.49414173, -0.44266973])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '800_LeadingJet_Forward_Data_pt': [[array([814.576    , 892.6746875, 816.82375  , ..., 809.1475625,
#           899.55375  , 925.3234375])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '800_LeadingJet_Forward_Data_eta': [[array([-0.87908328, -1.09978437, -0.95311534, ..., -1.24420059,
#           -1.37427819, -1.63592851])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '800_LeadingJet_Forward_Data_ntrk': [[array([13., 29.,  8., ..., 10., 13., 38.])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '800_LeadingJet_Forward_Data_width': [[array([0.01210182, 0.08197039, 0.00992426, ..., 0.04882229, 0.02145885,
#           0.10041228])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '800_LeadingJet_Forward_Data_c1': [[array([0.09929039, 0.26171461, 0.13773403, ..., 0.22959538, 0.19539021,
#           0.211908  ])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '800_LeadingJet_Forward_Data_bdt': [[array([-0.32534614,  0.16611271, -0.46125343, ..., -0.25349128,
#           -0.15142807,  0.1522001 ])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '800_LeadingJet_Forward_Data_newBDT': [[array([-0.4171636 , -0.01969866, -0.51412855, ..., -0.42956435,
#           -0.33000023, -0.0225372 ])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1000_LeadingJet_Forward_Data_pt': [[array([1198.307625 , 1107.29125  , 1050.51675  , ..., 1033.5506875,
#           1133.428    , 1022.5360625])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1000_LeadingJet_Forward_Data_eta': [[array([-0.80588573, -1.26326978, -0.73825473, ...,  1.37965071,
#            1.16729712, -1.43680692])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1000_LeadingJet_Forward_Data_ntrk': [[array([24., 30., 31., ..., 17., 14., 38.])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1000_LeadingJet_Forward_Data_width': [[array([0.01899855, 0.03921353, 0.09177066, ..., 0.02820337, 0.06011898,
#           0.1158505 ])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1000_LeadingJet_Forward_Data_c1': [[array([0.15988226, 0.25377399, 0.27709457, ..., 0.19734555, 0.23180194,
#           0.30218413])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1000_LeadingJet_Forward_Data_bdt': [[array([ 0.03472834,  0.26288289,  0.11783773, ..., -0.09100015,
#           -0.13587947,  0.23100677])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1000_LeadingJet_Forward_Data_newBDT': [[array([-0.01286486,  0.19701649,  0.15954338, ..., -0.19913582,
#           -0.23246906,  0.10328786])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1200_LeadingJet_Forward_Data_pt': [[array([1316.324625, 1262.860875, 1220.38425 , ..., 1247.066   ,
#           1357.5545  , 1251.829125])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1200_LeadingJet_Forward_Data_eta': [[array([ 1.29491258, -0.87492174, -0.92867601, ...,  1.54583657,
#            0.59719205,  0.07715298])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1200_LeadingJet_Forward_Data_ntrk': [[array([17., 12., 25., ..., 30., 19., 13.])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1200_LeadingJet_Forward_Data_width': [[array([0.01400989, 0.01175109, 0.029308  , ..., 0.07910499, 0.03674641,
#           0.01349395])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1200_LeadingJet_Forward_Data_c1': [[array([0.17095986, 0.10900547, 0.21088155, ..., 0.26956442, 0.23509853,
#           0.02155747])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1200_LeadingJet_Forward_Data_bdt': [[array([-0.11839528, -0.42990223,  0.15900917, ...,  0.07431586,
#           -0.04693834, -0.39546147])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1200_LeadingJet_Forward_Data_newBDT': [[array([-0.28782334, -0.45237267,  0.08624391, ..., -0.05345665,
#           -0.06157506, -0.37542184])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1500_LeadingJet_Forward_Data_pt': [[array([1531.087   , 1538.88125 , 1704.796875, ..., 1673.105625,
#           1813.808875, 1541.397375])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1500_LeadingJet_Forward_Data_eta': [[array([-0.28412479,  1.17533195, -0.29952651, ..., -0.58268386,
#           -0.4218564 , -0.24200694])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1500_LeadingJet_Forward_Data_ntrk': [[array([15., 16., 38., ..., 13.,  9., 16.])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1500_LeadingJet_Forward_Data_width': [[array([0.01633826, 0.0234824 , 0.08173604, ..., 0.04197424, 0.01164012,
#           0.02985519])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1500_LeadingJet_Forward_Data_c1': [[array([0.11614423, 0.18390024, 0.28411356, ..., 0.02618763, 0.12568438,
#           0.15569609])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1500_LeadingJet_Forward_Data_bdt': [[array([-0.33731797, -0.23650606,  0.18006927, ..., -0.29630232,
#           -0.56146032, -0.24197648])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1500_LeadingJet_Forward_Data_newBDT': [[array([-0.23545581, -0.29402203,  0.3196263 , ..., -0.35358143,
#           -0.4992801 , -0.20294441])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '500_LeadingJet_Central_Data_pt': [[array([505.81125   , 538.065875  , 560.05975   , ..., 532.4930625 ,
#           506.87678125, 506.5978125 ])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '500_LeadingJet_Central_Data_eta': [[array([-0.04107272,  0.25302669,  0.4490712 , ..., -0.35590547,
#            0.08944152,  0.42132345])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '500_LeadingJet_Central_Data_ntrk': [[array([ 9., 15., 22., ..., 18., 17., 33.])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '500_LeadingJet_Central_Data_width': [[array([0.03421819, 0.07410899, 0.05686455, ..., 0.04827519, 0.04009419,
#           0.16119072])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '500_LeadingJet_Central_Data_c1': [[array([0.09595761, 0.25475129, 0.23560399, ..., 0.23533937, 0.21379487,
#           0.30113333])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '500_LeadingJet_Central_Data_bdt': [[array([-0.2973291 , -0.06214265,  0.11183831, ...,  0.07436693,
#            0.05379028,  0.23418799])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '500_LeadingJet_Central_Data_newBDT': [[array([-0.33700229, -0.00706124,  0.19355807, ...,  0.08740474,
#            0.10664378,  0.29093318])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '600_LeadingJet_Central_Data_pt': [[array([613.0408125, 614.636625 , 652.7535   , ..., 738.5229375,
#           731.29875  , 664.0041875])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '600_LeadingJet_Central_Data_eta': [[array([ 0.25314662, -0.59871894,  0.02726553, ..., -0.13065244,
#            0.54155898,  0.47324529])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '600_LeadingJet_Central_Data_ntrk': [[array([25., 27., 13., ..., 16., 27., 26.])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '600_LeadingJet_Central_Data_width': [[array([0.08072312, 0.06096383, 0.05597356, ..., 0.04719026, 0.04899611,
#           0.19622885])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '600_LeadingJet_Central_Data_c1': [[array([0.26868412, 0.2489195 , 0.2525472 , ..., 0.1898286 , 0.18960424,
#           0.30484259])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '600_LeadingJet_Central_Data_bdt': [[array([ 0.16562194,  0.21578906, -0.08449332, ..., -0.10653975,
#            0.05811739,  0.07578221])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '600_LeadingJet_Central_Data_newBDT': [[array([ 0.20951352,  0.25345045, -0.05684834, ..., -0.11070873,
#            0.13567193,  0.07498337])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '800_LeadingJet_Central_Data_pt': [[array([848.594    , 820.17575  , 990.7690625, ..., 846.390375 ,
#           834.3825   , 836.30525  ])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '800_LeadingJet_Central_Data_eta': [[array([-0.17831808, -0.88561118,  0.19800198, ..., -0.06178527,
#           -0.28560802,  0.33082154])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '800_LeadingJet_Central_Data_ntrk': [[array([15., 18., 23., ...,  8., 19., 24.])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '800_LeadingJet_Central_Data_width': [[array([0.0120549 , 0.05172899, 0.02839754, ..., 0.01241104, 0.06004821,
#           0.08791302])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '800_LeadingJet_Central_Data_c1': [[array([0.15209921, 0.23221602, 0.23437136, ..., 0.12443207, 0.25995421,
#           0.1788059 ])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '800_LeadingJet_Central_Data_bdt': [[array([-0.14030001, -0.03921393,  0.19387917, ..., -0.48602083,
#           -0.00218156, -0.10936029])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '800_LeadingJet_Central_Data_newBDT': [[array([-0.24023256, -0.17977379,  0.11046666, ..., -0.50574506,
#           -0.00708366, -0.02936124])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1000_LeadingJet_Central_Data_pt': [[array([1112.3325   , 1052.566375 , 1127.1095   , ..., 1106.86625  ,
#           1044.2816875, 1020.8779375])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1000_LeadingJet_Central_Data_eta': [[array([ 1.45365393, -0.40417993, -1.27293646, ..., -0.05516636,
#           -0.08862669, -0.1363498 ])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1000_LeadingJet_Central_Data_ntrk': [[array([21., 21., 25., ..., 30., 49., 38.])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1000_LeadingJet_Central_Data_width': [[array([0.0386082 , 0.03814297, 0.01734455, ..., 0.06609438, 0.11834038,
#           0.05403378])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1000_LeadingJet_Central_Data_c1': [[array([0.23650214, 0.23830436, 0.16452593, ..., 0.2371611 , 0.29492137,
#           0.26199362])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1000_LeadingJet_Central_Data_bdt': [[array([-0.00828372,  0.05070717,  0.19969118, ...,  0.11903803,
#            0.35573217,  0.37042511])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1000_LeadingJet_Central_Data_newBDT': [[array([-0.16631377,  0.06401815, -0.05514087, ...,  0.21955632,
#            0.42931342,  0.40466652])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1200_LeadingJet_Central_Data_pt': [[array([1295.030625, 1250.133875, 1378.21325 , ..., 1277.6685  ,
#           1327.185125, 1226.567875])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1200_LeadingJet_Central_Data_eta': [[array([-0.08009642, -0.49872085,  0.74148053, ...,  0.14904827,
#           -0.31104273,  0.20385018])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1200_LeadingJet_Central_Data_ntrk': [[array([18., 10., 20., ..., 15., 15., 14.])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1200_LeadingJet_Central_Data_width': [[array([0.01709856, 0.00901037, 0.02080095, ..., 0.02239045, 0.02000603,
#           0.00916257])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1200_LeadingJet_Central_Data_c1': [[array([0.17069326, 0.06719469, 0.19364452, ..., 0.20480037, 0.16318142,
#           0.10608817])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1200_LeadingJet_Central_Data_bdt': [[array([-0.08813726, -0.51382416,  0.01387667, ..., -0.10520476,
#           -0.19920513, -0.3175239 ])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1200_LeadingJet_Central_Data_newBDT': [[array([-0.13697461, -0.54127453,  0.05245613, ..., -0.09848447,
#           -0.15824684, -0.38713031])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1500_LeadingJet_Central_Data_pt': [[array([1754.740125, 1631.919875, 1539.743375, ..., 1724.803875,
#           1667.071625, 1551.214   ])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1500_LeadingJet_Central_Data_eta': [[array([ 0.13953668,  0.4332284 ,  0.17223682, ..., -0.26571858,
#            0.3595542 ,  0.0379288 ])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1500_LeadingJet_Central_Data_ntrk': [[array([25., 20., 10., ..., 23., 26.,  9.])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1500_LeadingJet_Central_Data_width': [[array([0.04532899, 0.01989963, 0.01973316, ..., 0.08307445, 0.019359  ,
#           0.01976163])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1500_LeadingJet_Central_Data_c1': [[array([0.21983184, 0.14748949, 0.1435833 , ..., 0.23022966, 0.17502108,
#           0.02481699])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1500_LeadingJet_Central_Data_bdt': [[array([-0.00690368, -0.13554324, -0.42402768, ..., -0.09007514,
#            0.10550158, -0.49237239])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1500_LeadingJet_Central_Data_newBDT': [[array([ 0.07583912, -0.07393926, -0.3923049 , ..., -0.11396489,
#            0.05660512, -0.48015951])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '500_SubJet_Forward_Data_pt': [[array([555.2509375 , 534.354125  , 500.096375  , ..., 500.2048125 ,
#           503.48115625, 570.7629375 ])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '500_SubJet_Forward_Data_eta': [[array([ 1.54821575, -0.57291275,  1.88722968, ...,  1.26929605,
#            1.22205555,  1.59701359])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '500_SubJet_Forward_Data_ntrk': [[array([22., 15., 19., ...,  9., 11., 19.])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '500_SubJet_Forward_Data_width': [[array([0.04300692, 0.06730336, 0.03015146, ..., 0.02696359, 0.02693217,
#           0.01824242])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '500_SubJet_Forward_Data_c1': [[array([0.22204855, 0.25023302, 0.18644498, ..., 0.19230688, 0.19755307,
#           0.20649862])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '500_SubJet_Forward_Data_bdt': [[array([ 0.12292557, -0.06891783,  0.0093466 , ..., -0.27789807,
#           -0.18861574,  0.08040839])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '500_SubJet_Forward_Data_newBDT': [[array([ 0.08594334,  0.02943062, -0.16381165, ..., -0.16760367,
#           -0.15022677,  0.01077144])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '600_SubJet_Forward_Data_pt': [[array([600.0964375, 743.2651875, 739.7155625, ..., 601.386125 ,
#           695.925125 , 653.6589375])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '600_SubJet_Forward_Data_eta': [[array([-0.5857445 , -1.22897732,  1.40161943, ..., -1.19203293,
#            1.36683452,  0.76124644])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '600_SubJet_Forward_Data_ntrk': [[array([19., 12., 42., ..., 29., 23., 24.])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '600_SubJet_Forward_Data_width': [[array([0.02401266, 0.08491912, 0.17762694, ..., 0.09307933, 0.02932356,
#           0.04295792])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '600_SubJet_Forward_Data_c1': [[array([0.18819429, 0.20379944, 0.33402169, ..., 0.27666831, 0.18685573,
#           0.23069848])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '600_SubJet_Forward_Data_bdt': [[array([ 0.10876621, -0.1273458 ,  0.26502284, ...,  0.21806723,
#            0.08078874,  0.18589252])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '600_SubJet_Forward_Data_newBDT': [[array([ 0.09110887, -0.32510906,  0.20550384, ...,  0.20544729,
#            0.04357889,  0.24682447])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '800_SubJet_Forward_Data_pt': [[array([884.9705625, 822.6044375, 855.2370625, ..., 808.640875 ,
#           850.5598125, 822.6066875])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '800_SubJet_Forward_Data_eta': [[array([-1.52546155, -0.48355201,  1.00344133, ..., -1.04498208,
#            1.39861035, -0.59754962])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '800_SubJet_Forward_Data_ntrk': [[array([ 9., 27., 16., ..., 10., 14., 20.])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '800_SubJet_Forward_Data_width': [[array([0.01447282, 0.03064885, 0.06843538, ..., 0.01659466, 0.01106437,
#           0.02552896])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '800_SubJet_Forward_Data_c1': [[array([0.14022505, 0.20702969, 0.23427723, ..., 0.12881966, 0.14209789,
#           0.1792509 ])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '800_SubJet_Forward_Data_bdt': [[array([-0.45288476,  0.25763491, -0.11079702, ..., -0.40085718,
#           -0.26503611,  0.05782906])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '800_SubJet_Forward_Data_newBDT': [[array([-0.58318763,  0.14964469, -0.22134534, ..., -0.4430461 ,
#           -0.48265749, -0.03548058])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1000_SubJet_Forward_Data_pt': [[array([1051.161375, 1025.8135  , 1052.638625, ..., 1067.35625 ,
#           1141.936125, 1128.4985  ])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1000_SubJet_Forward_Data_eta': [[array([ 0.95640987,  1.27574956,  1.53170121, ...,  0.78806996,
#           -0.65671027,  1.30483317])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1000_SubJet_Forward_Data_ntrk': [[array([27., 17., 13., ..., 16., 14., 16.])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1000_SubJet_Forward_Data_width': [[array([0.07919005, 0.01083965, 0.00827624, ..., 0.02696417, 0.0153465 ,
#           0.02717398])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1000_SubJet_Forward_Data_c1': [[array([0.2121271 , 0.10800012, 0.0447248 , ..., 0.17243533, 0.16559914,
#           0.04100212])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1000_SubJet_Forward_Data_bdt': [[array([ 0.00958073, -0.16255923, -0.39848554, ..., -0.14332299,
#           -0.21480367, -0.20649588])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1000_SubJet_Forward_Data_newBDT': [[array([-0.07124439, -0.31469914, -0.59902126, ..., -0.24296642,
#           -0.25838045, -0.37241483])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1200_SubJet_Forward_Data_pt': [[array([1286.233125, 1269.695625, 1319.90625 , ..., 1225.158625,
#           1225.496375, 1358.909625])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1200_SubJet_Forward_Data_eta': [[array([-0.55373502, -0.77491635,  0.7599842 , ...,  0.80408847,
#           -0.14221773, -1.06630516])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1200_SubJet_Forward_Data_ntrk': [[array([ 6., 25., 12., ..., 35., 24., 26.])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1200_SubJet_Forward_Data_width': [[array([0.02464527, 0.03599198, 0.01780129, ..., 0.12925018, 0.11077966,
#           0.04049825])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1200_SubJet_Forward_Data_c1': [[array([0.16603029, 0.23655295, 0.18449019, ..., 0.27568424, 0.29017317,
#           0.16780224])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1200_SubJet_Forward_Data_bdt': [[array([-0.43801823,  0.13929974, -0.30059737, ...,  0.10360251,
#            0.04353427, -0.01705844])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1200_SubJet_Forward_Data_newBDT': [[array([-0.46594811,  0.05198419, -0.32385284, ...,  0.15000806,
#            0.03442726, -0.02391009])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1500_SubJet_Forward_Data_pt': [[array([1611.450625, 1548.480375, 1509.748875, ..., 1690.681   ,
#           1642.15625 , 1513.213   ])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1500_SubJet_Forward_Data_eta': [[array([-0.56315958, -0.51538283,  1.22189951, ..., -0.68209034,
#            0.469264  , -0.41597629])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1500_SubJet_Forward_Data_ntrk': [[array([40., 16., 40., ..., 18., 15., 19.])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1500_SubJet_Forward_Data_width': [[array([0.11919983, 0.0065058 , 0.06195457, ..., 0.0037458 , 0.01409478,
#           0.01172251])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1500_SubJet_Forward_Data_c1': [[array([0.29180849, 0.00174982, 0.23518004, ..., 0.02925444, 0.17225111,
#           0.16551618])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1500_SubJet_Forward_Data_bdt': [[array([ 0.1179378 , -0.29041204,  0.19073543, ..., -0.21238762,
#           -0.24224694, -0.09915636])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1500_SubJet_Forward_Data_newBDT': [[array([ 0.3128695 , -0.26826407,  0.21828204, ..., -0.23233479,
#           -0.18059984, -0.10382401])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '500_SubJet_Central_Data_pt': [[array([566.184     , 525.653625  , 505.78059375, ..., 586.352125  ,
#           587.4949375 , 561.5074375 ])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '500_SubJet_Central_Data_eta': [[array([-0.39078212,  0.22957896,  0.33379036, ...,  0.09051771,
#           -0.07615675,  0.62052172])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '500_SubJet_Central_Data_ntrk': [[array([14., 14.,  7., ..., 19., 42., 18.])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '500_SubJet_Central_Data_width': [[array([0.05921139, 0.03576477, 0.01815192, ..., 0.03119385, 0.10593592,
#           0.02654168])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '500_SubJet_Central_Data_c1': [[array([0.20569159, 0.22559258, 0.13460782, ..., 0.20810667, 0.29819697,
#           0.20245036])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '500_SubJet_Central_Data_bdt': [[array([-0.11442338, -0.03200821, -0.44307682, ...,  0.11932021,
#            0.40575999,  0.09463134])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '500_SubJet_Central_Data_newBDT': [[array([-0.01144578,  0.06545916, -0.322623  , ...,  0.16326507,
#            0.42301924,  0.15741319])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '600_SubJet_Central_Data_pt': [[array([723.56     , 647.818125 , 647.65025  , ..., 625.835125 ,
#           701.908125 , 625.0005625])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '600_SubJet_Central_Data_eta': [[array([ 0.49022937,  0.82151639,  0.28969893, ...,  0.6108067 ,
#           -0.3478736 ,  0.53486586])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '600_SubJet_Central_Data_ntrk': [[array([25., 24., 36., ..., 26., 36., 12.])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '600_SubJet_Central_Data_width': [[array([0.1078814 , 0.07103954, 0.1038365 , ..., 0.16717309, 0.06996831,
#           0.02813202])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '600_SubJet_Central_Data_c1': [[array([0.29293603, 0.23274751, 0.23839103, ..., 0.29299241, 0.26302838,
#           0.19227457])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '600_SubJet_Central_Data_bdt': [[array([ 0.09245615,  0.08100182,  0.21685173, ...,  0.06459149,
#            0.34422547, -0.13720195])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '600_SubJet_Central_Data_newBDT': [[array([ 0.11467797,  0.10148479,  0.24372893, ...,  0.09499602,
#            0.37775649, -0.15905831])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '800_SubJet_Central_Data_pt': [[array([809.1328125, 858.9280625, 915.004625 , ..., 999.8208125,
#           851.6491875, 835.3518125])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '800_SubJet_Central_Data_eta': [[array([ 0.02471456, -0.84053397,  0.41731715, ...,  0.46227145,
#            0.77847451,  0.90930831])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '800_SubJet_Central_Data_ntrk': [[array([16., 14., 35., ..., 18., 36., 14.])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '800_SubJet_Central_Data_width': [[array([0.04715524, 0.04559608, 0.03551897, ..., 0.02768323, 0.1658622 ,
#           0.02094159])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '800_SubJet_Central_Data_c1': [[array([0.19199613, 0.22942413, 0.23785572, ..., 0.18891355, 0.33907095,
#           0.11956904])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '800_SubJet_Central_Data_bdt': [[array([-0.09595942, -0.08473081,  0.41417792, ..., -0.00604139,
#            0.1967589 , -0.25748312])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '800_SubJet_Central_Data_newBDT': [[array([-0.16969046, -0.23128276,  0.3475835 , ..., -0.13328125,
#            0.20943668, -0.34938479])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1000_SubJet_Central_Data_pt': [[array([1038.9623125, 1010.554125 , 1097.13475  , ..., 1064.764875 ,
#           1092.062    , 1119.751125 ])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1000_SubJet_Central_Data_eta': [[array([-0.1442112 , -0.45460019,  0.20658447, ...,  0.32466403,
#           -0.35389748, -0.10350363])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1000_SubJet_Central_Data_ntrk': [[array([23., 31., 10., ..., 10., 65., 42.])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1000_SubJet_Central_Data_width': [[array([0.03542791, 0.0487969 , 0.01179888, ..., 0.01315688, 0.1038053 ,
#           0.11048201])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1000_SubJet_Central_Data_c1': [[array([0.22024585, 0.24983975, 0.16508619, ..., 0.15731114, 0.30523556,
#           0.29635543])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1000_SubJet_Central_Data_bdt': [[array([ 0.10696119,  0.26490936, -0.44597402, ..., -0.42937037,
#            0.48374039,  0.27103248])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1000_SubJet_Central_Data_newBDT': [[array([ 0.04276761,  0.24462265, -0.39946648, ..., -0.35414991,
#            0.46549514,  0.32369235])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1200_SubJet_Central_Data_pt': [[array([1282.217125, 1271.096625, 1227.265   , ..., 1357.71025 ,
#           1330.846625, 1233.459625])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1200_SubJet_Central_Data_eta': [[array([-0.34794497, -0.42208332,  0.31626493, ...,  0.02347714,
#           -0.04714879, -0.01969299])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1200_SubJet_Central_Data_ntrk': [[array([17., 24., 16., ..., 41., 12., 22.])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1200_SubJet_Central_Data_width': [[array([0.05094396, 0.04080339, 0.02737809, ..., 0.15592189, 0.01451687,
#           0.01470423])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1200_SubJet_Central_Data_c1': [[array([0.1520679 , 0.18415156, 0.20623745, ..., 0.31402475, 0.0940035 ,
#           0.15099315])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1200_SubJet_Central_Data_bdt': [[array([-0.1379267 , -0.07151563, -0.07641751, ...,  0.18641779,
#           -0.43504435,  0.11368812])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1200_SubJet_Central_Data_newBDT': [[array([-0.253229  ,  0.04117703, -0.12236618, ...,  0.33033202,
#           -0.4176983 , -0.06798008])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1500_SubJet_Central_Data_pt': [[array([1507.669875, 1518.439375, 1682.055   , ..., 1510.15625 ,
#           1572.3995  , 1665.535625])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1500_SubJet_Central_Data_eta': [[array([-0.02154499,  0.47640297,  0.22922602, ..., -0.03645981,
#           -0.65441084,  0.46722072])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1500_SubJet_Central_Data_ntrk': [[array([40., 16., 37., ..., 38., 10.,  5.])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1500_SubJet_Central_Data_width': [[array([0.13977493, 0.02004714, 0.02466631, ..., 0.17311795, 0.00686805,
#           0.09552775])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1500_SubJet_Central_Data_c1': [[array([0.29402375, 0.15999775, 0.22110489, ..., 0.30814028, 0.13148369,
#           0.21813512])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1500_SubJet_Central_Data_bdt': [[array([ 0.14353605, -0.21311666,  0.3083888 , ...,  0.12866014,
#           -0.54153001, -0.25166813])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]],
#  '1500_SubJet_Central_Data_newBDT': [[array([ 0.29610524, -0.21328426,  0.31893044, ...,  0.23889152,
#           -0.54498801, -0.38171801])],
#   [array([1., 1., 1., ..., 1., 1., 1.])]]}

# %%
foutput = uproot.recreate("./dijet_pythia_data1516.root")

# %%
for hist in HistMap.keys():
    print(hist)
    nbin,binmin,binmax = GetHistBin(hist)
    histogram = np.histogram(a = HistMap[hist][0], weights = HistMap[hist][1], bins = nbin, range = (binmin,binmax))
    #print(histogram)
    foutput[hist] = histogram

    weight = np.array(HistMap[hist][1])
    binning = np.linspace(binmin,binmax,nbin)
    sum_w2 = np.zeros([nbin], dtype=np.float32)
    digits = np.digitize(HistMap[hist][0],binning)
    for i in range(nbin):
        weights_in_current_bin = weight[0][np.where(digits == i)[0]]
        sum_w2[i] = np.sum(np.power(weights_in_current_bin, 2))
    #print(sum_w2)
    histogram_err = np.histogram(a = binning, weights = sum_w2, bins = nbin, range = (binmin,binmax))
    foutput[hist+"_err"] = histogram_err
# Out:
# 500_LeadingJet_Forward_Data_pt
# 500_LeadingJet_Forward_Data_eta
# 500_LeadingJet_Forward_Data_ntrk
# 500_LeadingJet_Forward_Data_width
# 500_LeadingJet_Forward_Data_c1
# 500_LeadingJet_Forward_Data_bdt
# 500_LeadingJet_Forward_Data_newBDT
# 600_LeadingJet_Forward_Data_pt
# 600_LeadingJet_Forward_Data_eta
# 600_LeadingJet_Forward_Data_ntrk
# 600_LeadingJet_Forward_Data_width
# 600_LeadingJet_Forward_Data_c1
# 600_LeadingJet_Forward_Data_bdt
# 600_LeadingJet_Forward_Data_newBDT
# 800_LeadingJet_Forward_Data_pt
# 800_LeadingJet_Forward_Data_eta
# 800_LeadingJet_Forward_Data_ntrk
# 800_LeadingJet_Forward_Data_width
# 800_LeadingJet_Forward_Data_c1
# 800_LeadingJet_Forward_Data_bdt
# 800_LeadingJet_Forward_Data_newBDT
# 1000_LeadingJet_Forward_Data_pt
# 1000_LeadingJet_Forward_Data_eta
# 1000_LeadingJet_Forward_Data_ntrk
# 1000_LeadingJet_Forward_Data_width
# 1000_LeadingJet_Forward_Data_c1
# 1000_LeadingJet_Forward_Data_bdt
# 1000_LeadingJet_Forward_Data_newBDT
# 1200_LeadingJet_Forward_Data_pt
# 1200_LeadingJet_Forward_Data_eta
# 1200_LeadingJet_Forward_Data_ntrk
# 1200_LeadingJet_Forward_Data_width
# 1200_LeadingJet_Forward_Data_c1
# 1200_LeadingJet_Forward_Data_bdt
# 1200_LeadingJet_Forward_Data_newBDT
# 1500_LeadingJet_Forward_Data_pt
# 1500_LeadingJet_Forward_Data_eta
# 1500_LeadingJet_Forward_Data_ntrk
# 1500_LeadingJet_Forward_Data_width
# 1500_LeadingJet_Forward_Data_c1
# 1500_LeadingJet_Forward_Data_bdt
# 1500_LeadingJet_Forward_Data_newBDT
# 500_LeadingJet_Central_Data_pt
# 500_LeadingJet_Central_Data_eta
# 500_LeadingJet_Central_Data_ntrk
# 500_LeadingJet_Central_Data_width
# 500_LeadingJet_Central_Data_c1
# 500_LeadingJet_Central_Data_bdt
# 500_LeadingJet_Central_Data_newBDT
# 600_LeadingJet_Central_Data_pt
# 600_LeadingJet_Central_Data_eta
# 600_LeadingJet_Central_Data_ntrk
# 600_LeadingJet_Central_Data_width
# 600_LeadingJet_Central_Data_c1
# 600_LeadingJet_Central_Data_bdt
# 600_LeadingJet_Central_Data_newBDT
# 800_LeadingJet_Central_Data_pt
# 800_LeadingJet_Central_Data_eta
# 800_LeadingJet_Central_Data_ntrk
# 800_LeadingJet_Central_Data_width
# 800_LeadingJet_Central_Data_c1
# 800_LeadingJet_Central_Data_bdt
# 800_LeadingJet_Central_Data_newBDT
# 1000_LeadingJet_Central_Data_pt
# 1000_LeadingJet_Central_Data_eta
# 1000_LeadingJet_Central_Data_ntrk
# 1000_LeadingJet_Central_Data_width
# 1000_LeadingJet_Central_Data_c1
# 1000_LeadingJet_Central_Data_bdt
# 1000_LeadingJet_Central_Data_newBDT
# 1200_LeadingJet_Central_Data_pt
# 1200_LeadingJet_Central_Data_eta
# 1200_LeadingJet_Central_Data_ntrk
# 1200_LeadingJet_Central_Data_width
# 1200_LeadingJet_Central_Data_c1
# 1200_LeadingJet_Central_Data_bdt
# 1200_LeadingJet_Central_Data_newBDT
# 1500_LeadingJet_Central_Data_pt
# 1500_LeadingJet_Central_Data_eta
# 1500_LeadingJet_Central_Data_ntrk
# 1500_LeadingJet_Central_Data_width
# 1500_LeadingJet_Central_Data_c1
# 1500_LeadingJet_Central_Data_bdt
# 1500_LeadingJet_Central_Data_newBDT
# 500_SubJet_Forward_Data_pt
# 500_SubJet_Forward_Data_eta
# 500_SubJet_Forward_Data_ntrk
# 500_SubJet_Forward_Data_width
# 500_SubJet_Forward_Data_c1
# 500_SubJet_Forward_Data_bdt
# 500_SubJet_Forward_Data_newBDT
# 600_SubJet_Forward_Data_pt
# 600_SubJet_Forward_Data_eta
# 600_SubJet_Forward_Data_ntrk
# 600_SubJet_Forward_Data_width
# 600_SubJet_Forward_Data_c1
# 600_SubJet_Forward_Data_bdt
# 600_SubJet_Forward_Data_newBDT
# 800_SubJet_Forward_Data_pt
# 800_SubJet_Forward_Data_eta
# 800_SubJet_Forward_Data_ntrk
# 800_SubJet_Forward_Data_width
# 800_SubJet_Forward_Data_c1
# 800_SubJet_Forward_Data_bdt
# 800_SubJet_Forward_Data_newBDT
# 1000_SubJet_Forward_Data_pt
# 1000_SubJet_Forward_Data_eta
# 1000_SubJet_Forward_Data_ntrk
# 1000_SubJet_Forward_Data_width
# 1000_SubJet_Forward_Data_c1
# 1000_SubJet_Forward_Data_bdt
# 1000_SubJet_Forward_Data_newBDT
# 1200_SubJet_Forward_Data_pt
# 1200_SubJet_Forward_Data_eta
# 1200_SubJet_Forward_Data_ntrk
# 1200_SubJet_Forward_Data_width
# 1200_SubJet_Forward_Data_c1
# 1200_SubJet_Forward_Data_bdt
# 1200_SubJet_Forward_Data_newBDT
# 1500_SubJet_Forward_Data_pt
# 1500_SubJet_Forward_Data_eta
# 1500_SubJet_Forward_Data_ntrk
# 1500_SubJet_Forward_Data_width
# 1500_SubJet_Forward_Data_c1
# 1500_SubJet_Forward_Data_bdt
# 1500_SubJet_Forward_Data_newBDT
# 500_SubJet_Central_Data_pt
# 500_SubJet_Central_Data_eta
# 500_SubJet_Central_Data_ntrk
# 500_SubJet_Central_Data_width
# 500_SubJet_Central_Data_c1
# 500_SubJet_Central_Data_bdt
# 500_SubJet_Central_Data_newBDT
# 600_SubJet_Central_Data_pt
# 600_SubJet_Central_Data_eta
# 600_SubJet_Central_Data_ntrk
# 600_SubJet_Central_Data_width
# 600_SubJet_Central_Data_c1
# 600_SubJet_Central_Data_bdt
# 600_SubJet_Central_Data_newBDT
# 800_SubJet_Central_Data_pt
# 800_SubJet_Central_Data_eta
# 800_SubJet_Central_Data_ntrk
# 800_SubJet_Central_Data_width
# 800_SubJet_Central_Data_c1
# 800_SubJet_Central_Data_bdt
# 800_SubJet_Central_Data_newBDT
# 1000_SubJet_Central_Data_pt
# 1000_SubJet_Central_Data_eta
# 1000_SubJet_Central_Data_ntrk
# 1000_SubJet_Central_Data_width
# 1000_SubJet_Central_Data_c1
# 1000_SubJet_Central_Data_bdt
# 1000_SubJet_Central_Data_newBDT
# 1200_SubJet_Central_Data_pt
# 1200_SubJet_Central_Data_eta
# 1200_SubJet_Central_Data_ntrk
# 1200_SubJet_Central_Data_width
# 1200_SubJet_Central_Data_c1
# 1200_SubJet_Central_Data_bdt
# 1200_SubJet_Central_Data_newBDT
# 1500_SubJet_Central_Data_pt
# 1500_SubJet_Central_Data_eta
# 1500_SubJet_Central_Data_ntrk
# 1500_SubJet_Central_Data_width
# 1500_SubJet_Central_Data_c1
# 1500_SubJet_Central_Data_bdt
# 1500_SubJet_Central_Data_newBDT
