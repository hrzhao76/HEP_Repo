# %%
import joblib
import numpy as np 
from pathlib import Path

# %%
MC_hists = joblib.load('/global/cfs/projectdirs/atlas/hrzhao/HEP_Repo/QG_Calibration/tmp_test_whole/MC_hists.pkl')

# %%
MC_hists_dict = MC_hists

# %%
MC_hist_dicts_keys = [*MC_hists_dict]

# %%
merged_ADE_dict = MC_hists_dict[MC_hist_dicts_keys[0]][0]

# %%
for hists_file in MC_hists_dict[MC_hist_dicts_keys[0]][1:]:
            for k in merged_ADE_dict:
                merged_ADE_dict[k] += hists_file[k]

# %%
for other_key in MC_hist_dicts_keys[1:]: # ['D', 'E']
            for hists_file in MC_hists_dict[other_key]:
                for k in merged_ADE_dict: 
                    merged_ADE_dict[k] += hists_file[k]

# %%
len(merged_ADE_dict.keys())
# Out:
# 672

# %%
reweight_factor = joblib.load('/global/cfs/projectdirs/atlas/hrzhao/HEP_Repo/QG_Calibration/tmp_test_whole/reweight_factor.pkl')

# %%
reweight_factor2 = joblib.load('/global/cfs/projectdirs/atlas/hrzhao/HEP_Repo/QG_Calibration/NewWorkflow_dev/test_reweight/test_reweight_factor2.pkl')

# %%
reweight_factor[500]['jet_nTracks']['quark_factor']
# Out:
# array([0.        , 0.        , 0.76504383, 0.77453366, 0.78228986,
#        0.78910322, 0.80815286, 0.8349122 , 0.85043639, 0.87644848,
#        0.90028127, 0.93057548, 0.96142615, 0.98730172, 1.01508972,
#        1.03846653, 1.05588899, 1.075738  , 1.09366685, 1.110069  ,
#        1.12514566, 1.1222418 , 1.13719806, 1.15714548, 1.16301699,
#        1.182969  , 1.18455275, 1.1917966 , 1.19317652, 1.21329927,
#        1.221427  , 1.21577912, 1.22022633, 1.22589986, 1.25712537,
#        1.25063228, 1.27060326, 1.24808208, 1.31119057, 1.25645101,
#        1.23597459, 1.3256365 , 1.29446667, 1.31503331, 1.29904655,
#        1.23445892, 1.43688728, 1.22237645, 1.39451109, 1.50267667,
#        1.09579408, 1.18314577, 1.41519986, 1.39648542, 1.47515813,
#        0.86330381, 0.70737141, 1.35553626, 1.01694768, 1.5672156 ])

# %%
reweight_factor2[500]['jet_nTracks']['quark_factor']
# Out:
# array([0.        , 0.        , 0.76504383, 0.77453366, 0.78228986,
#        0.78910322, 0.80815286, 0.8349122 , 0.85043639, 0.87644848,
#        0.90028127, 0.93057548, 0.96142615, 0.98730172, 1.01508972,
#        1.03846653, 1.05588899, 1.075738  , 1.09366685, 1.110069  ,
#        1.12514566, 1.1222418 , 1.13719806, 1.15714548, 1.16301699,
#        1.182969  , 1.18455275, 1.1917966 , 1.19317652, 1.21329927,
#        1.221427  , 1.21577912, 1.22022633, 1.22589986, 1.25712537,
#        1.25063228, 1.27060326, 1.24808208, 1.31119057, 1.25645101,
#        1.23597459, 1.3256365 , 1.29446667, 1.31503331, 1.29904655,
#        1.23445892, 1.43688728, 1.22237645, 1.39451109, 1.50267667,
#        1.09579408, 1.18314577, 1.41519986, 1.39648542, 1.47515813,
#        0.86330381, 0.70737141, 1.35553626, 1.01694768, 1.5672156 ])

# %%
import uproot 

root_file = '/global/cfs/projectdirs/atlas/hrzhao/qgcal/Samples_New/data/data17/user.wasu.Oct18.data17_13TeV.periodD.physics_Main_minitrees.root/user.wasu.30894495._000001.minitrees.root'

# %%
root = uproot.open(root_file)

# %%
root
# Out:
# <ReadOnlyDirectory '/' at 0x155530289070>

# %% [markdown]
# # Test hists

# %%
hists_folder = '/global/cfs/projectdirs/atlas/hrzhao/HEP_Repo/QG_Calibration/tmp_test_whole'
hists_folder = Path(hists_folder)

# %%
hists_files = sorted(hists_folder.rglob("*_pred_hists.pkl"))

# %%
for hists_file in hists_files:
    if hists_file.stem.startswith("data"):
        print("Data")
    if hists_file.stem.startswith("data"):
        print("Data")
# Out:
# Data
# Data
# Data

# %%
hists_files[0]
# Out:
# PosixPath('/global/cfs/projectdirs/atlas/hrzhao/HEP_Repo/QG_Calibration/tmp_test_whole/data1516_pred_hists.pkl')

# %%
joblib.load(hists_files[0])
# Out:
# {'event_weight': {'500_LeadingJet_Forward_Data_jet_pt': Hist(Regular(60, 500, 2000, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=1.67437e+06, variance=1.67437e+06),
#   '500_LeadingJet_Forward_Data_jet_eta': Hist(Regular(50, -2.5, 2.5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=1.67437e+06, variance=1.67437e+06),
#   '500_LeadingJet_Forward_Data_jet_nTracks': Hist(Regular(60, 0, 60, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=1.67428e+06, variance=1.67428e+06) (WeightedSum(value=1.67437e+06, variance=1.67437e+06) with flow),
#   '500_LeadingJet_Forward_Data_jet_trackWidth': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=1.67307e+06, variance=1.67307e+06) (WeightedSum(value=1.67437e+06, variance=1.67437e+06) with flow),
#   '500_LeadingJet_Forward_Data_jet_trackC1': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=1.67308e+06, variance=1.67308e+06) (WeightedSum(value=1.67437e+06, variance=1.67437e+06) with flow),
#   '500_LeadingJet_Forward_Data_jet_trackBDT': Hist(Regular(100, -1, 1, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=1.67437e+06, variance=1.67437e+06),
#   '500_LeadingJet_Forward_Data_GBDT_newScore': Hist(Regular(100, -5, 5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=1.67437e+06, variance=1.67437e+06),
#   '500_LeadingJet_Central_Data_jet_pt': Hist(Regular(60, 500, 2000, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=1.63242e+06, variance=1.63242e+06),
#   '500_LeadingJet_Central_Data_jet_eta': Hist(Regular(50, -2.5, 2.5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=1.63242e+06, variance=1.63242e+06),
#   '500_LeadingJet_Central_Data_jet_nTracks': Hist(Regular(60, 0, 60, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=1.63232e+06, variance=1.63232e+06) (WeightedSum(value=1.63242e+06, variance=1.63242e+06) with flow),
#   '500_LeadingJet_Central_Data_jet_trackWidth': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=1.63135e+06, variance=1.63135e+06) (WeightedSum(value=1.63242e+06, variance=1.63242e+06) with flow),
#   '500_LeadingJet_Central_Data_jet_trackC1': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=1.63136e+06, variance=1.63136e+06) (WeightedSum(value=1.63242e+06, variance=1.63242e+06) with flow),
#   '500_LeadingJet_Central_Data_jet_trackBDT': Hist(Regular(100, -1, 1, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=1.63242e+06, variance=1.63242e+06),
#   '500_LeadingJet_Central_Data_GBDT_newScore': Hist(Regular(100, -5, 5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=1.63242e+06, variance=1.63242e+06),
#   '500_SubLeadingJet_Forward_Data_jet_pt': Hist(Regular(60, 500, 2000, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=2.86582e+06, variance=2.86582e+06),
#   '500_SubLeadingJet_Forward_Data_jet_eta': Hist(Regular(50, -2.5, 2.5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=2.86582e+06, variance=2.86582e+06),
#   '500_SubLeadingJet_Forward_Data_jet_nTracks': Hist(Regular(60, 0, 60, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=2.86561e+06, variance=2.86561e+06) (WeightedSum(value=2.86582e+06, variance=2.86582e+06) with flow),
#   '500_SubLeadingJet_Forward_Data_jet_trackWidth': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=2.86442e+06, variance=2.86442e+06) (WeightedSum(value=2.86582e+06, variance=2.86582e+06) with flow),
#   '500_SubLeadingJet_Forward_Data_jet_trackC1': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=2.86443e+06, variance=2.86443e+06) (WeightedSum(value=2.86582e+06, variance=2.86582e+06) with flow),
#   '500_SubLeadingJet_Forward_Data_jet_trackBDT': Hist(Regular(100, -1, 1, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=2.86582e+06, variance=2.86582e+06),
#   '500_SubLeadingJet_Forward_Data_GBDT_newScore': Hist(Regular(100, -5, 5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=2.86582e+06, variance=2.86582e+06),
#   '500_SubLeadingJet_Central_Data_jet_pt': Hist(Regular(60, 500, 2000, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=2.97707e+06, variance=2.97707e+06),
#   '500_SubLeadingJet_Central_Data_jet_eta': Hist(Regular(50, -2.5, 2.5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=2.97707e+06, variance=2.97707e+06),
#   '500_SubLeadingJet_Central_Data_jet_nTracks': Hist(Regular(60, 0, 60, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=2.97682e+06, variance=2.97682e+06) (WeightedSum(value=2.97707e+06, variance=2.97707e+06) with flow),
#   '500_SubLeadingJet_Central_Data_jet_trackWidth': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=2.97562e+06, variance=2.97562e+06) (WeightedSum(value=2.97707e+06, variance=2.97707e+06) with flow),
#   '500_SubLeadingJet_Central_Data_jet_trackC1': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=2.97563e+06, variance=2.97563e+06) (WeightedSum(value=2.97707e+06, variance=2.97707e+06) with flow),
#   '500_SubLeadingJet_Central_Data_jet_trackBDT': Hist(Regular(100, -1, 1, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=2.97707e+06, variance=2.97707e+06),
#   '500_SubLeadingJet_Central_Data_GBDT_newScore': Hist(Regular(100, -5, 5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=2.97707e+06, variance=2.97707e+06),
#   '600_LeadingJet_Forward_Data_jet_pt': Hist(Regular(60, 500, 2000, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=2.41502e+06, variance=2.41502e+06),
#   '600_LeadingJet_Forward_Data_jet_eta': Hist(Regular(50, -2.5, 2.5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=2.41502e+06, variance=2.41502e+06),
#   '600_LeadingJet_Forward_Data_jet_nTracks': Hist(Regular(60, 0, 60, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=2.41455e+06, variance=2.41455e+06) (WeightedSum(value=2.41502e+06, variance=2.41502e+06) with flow),
#   '600_LeadingJet_Forward_Data_jet_trackWidth': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=2.41259e+06, variance=2.41259e+06) (WeightedSum(value=2.41502e+06, variance=2.41502e+06) with flow),
#   '600_LeadingJet_Forward_Data_jet_trackC1': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=2.41261e+06, variance=2.41261e+06) (WeightedSum(value=2.41502e+06, variance=2.41502e+06) with flow),
#   '600_LeadingJet_Forward_Data_jet_trackBDT': Hist(Regular(100, -1, 1, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=2.41502e+06, variance=2.41502e+06),
#   '600_LeadingJet_Forward_Data_GBDT_newScore': Hist(Regular(100, -5, 5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=2.41502e+06, variance=2.41502e+06),
#   '600_LeadingJet_Central_Data_jet_pt': Hist(Regular(60, 500, 2000, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=2.31872e+06, variance=2.31872e+06),
#   '600_LeadingJet_Central_Data_jet_eta': Hist(Regular(50, -2.5, 2.5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=2.31872e+06, variance=2.31872e+06),
#   '600_LeadingJet_Central_Data_jet_nTracks': Hist(Regular(60, 0, 60, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=2.31818e+06, variance=2.31818e+06) (WeightedSum(value=2.31872e+06, variance=2.31872e+06) with flow),
#   '600_LeadingJet_Central_Data_jet_trackWidth': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=2.31688e+06, variance=2.31688e+06) (WeightedSum(value=2.31872e+06, variance=2.31872e+06) with flow),
#   '600_LeadingJet_Central_Data_jet_trackC1': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=2.31688e+06, variance=2.31688e+06) (WeightedSum(value=2.31872e+06, variance=2.31872e+06) with flow),
#   '600_LeadingJet_Central_Data_jet_trackBDT': Hist(Regular(100, -1, 1, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=2.31872e+06, variance=2.31872e+06),
#   '600_LeadingJet_Central_Data_GBDT_newScore': Hist(Regular(100, -5, 5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=2.31872e+06, variance=2.31872e+06),
#   '600_SubLeadingJet_Forward_Data_jet_pt': Hist(Regular(60, 500, 2000, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=1.43213e+06, variance=1.43213e+06),
#   '600_SubLeadingJet_Forward_Data_jet_eta': Hist(Regular(50, -2.5, 2.5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=1.43213e+06, variance=1.43213e+06),
#   '600_SubLeadingJet_Forward_Data_jet_nTracks': Hist(Regular(60, 0, 60, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=1.43171e+06, variance=1.43171e+06) (WeightedSum(value=1.43213e+06, variance=1.43213e+06) with flow),
#   '600_SubLeadingJet_Forward_Data_jet_trackWidth': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=1.43131e+06, variance=1.43131e+06) (WeightedSum(value=1.43213e+06, variance=1.43213e+06) with flow),
#   '600_SubLeadingJet_Forward_Data_jet_trackC1': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=1.43132e+06, variance=1.43132e+06) (WeightedSum(value=1.43213e+06, variance=1.43213e+06) with flow),
#   '600_SubLeadingJet_Forward_Data_jet_trackBDT': Hist(Regular(100, -1, 1, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=1.43213e+06, variance=1.43213e+06),
#   '600_SubLeadingJet_Forward_Data_GBDT_newScore': Hist(Regular(100, -5, 5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=1.43213e+06, variance=1.43213e+06),
#   '600_SubLeadingJet_Central_Data_jet_pt': Hist(Regular(60, 500, 2000, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=1.46805e+06, variance=1.46805e+06),
#   '600_SubLeadingJet_Central_Data_jet_eta': Hist(Regular(50, -2.5, 2.5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=1.46805e+06, variance=1.46805e+06),
#   '600_SubLeadingJet_Central_Data_jet_nTracks': Hist(Regular(60, 0, 60, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=1.4675e+06, variance=1.4675e+06) (WeightedSum(value=1.46805e+06, variance=1.46805e+06) with flow),
#   '600_SubLeadingJet_Central_Data_jet_trackWidth': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=1.46728e+06, variance=1.46728e+06) (WeightedSum(value=1.46805e+06, variance=1.46805e+06) with flow),
#   '600_SubLeadingJet_Central_Data_jet_trackC1': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=1.46729e+06, variance=1.46729e+06) (WeightedSum(value=1.46805e+06, variance=1.46805e+06) with flow),
#   '600_SubLeadingJet_Central_Data_jet_trackBDT': Hist(Regular(100, -1, 1, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=1.46805e+06, variance=1.46805e+06),
#   '600_SubLeadingJet_Central_Data_GBDT_newScore': Hist(Regular(100, -5, 5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=1.46805e+06, variance=1.46805e+06),
#   '800_LeadingJet_Forward_Data_jet_pt': Hist(Regular(60, 500, 2000, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=532363, variance=532363),
#   '800_LeadingJet_Forward_Data_jet_eta': Hist(Regular(50, -2.5, 2.5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=532363, variance=532363),
#   '800_LeadingJet_Forward_Data_jet_nTracks': Hist(Regular(60, 0, 60, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=531973, variance=531973) (WeightedSum(value=532363, variance=532363) with flow),
#   '800_LeadingJet_Forward_Data_jet_trackWidth': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=531696, variance=531696) (WeightedSum(value=532363, variance=532363) with flow),
#   '800_LeadingJet_Forward_Data_jet_trackC1': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=531698, variance=531698) (WeightedSum(value=532363, variance=532363) with flow),
#   '800_LeadingJet_Forward_Data_jet_trackBDT': Hist(Regular(100, -1, 1, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=532363, variance=532363),
#   '800_LeadingJet_Forward_Data_GBDT_newScore': Hist(Regular(100, -5, 5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=532363, variance=532363),
#   '800_LeadingJet_Central_Data_jet_pt': Hist(Regular(60, 500, 2000, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=522195, variance=522195),
#   '800_LeadingJet_Central_Data_jet_eta': Hist(Regular(50, -2.5, 2.5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=522195, variance=522195),
#   '800_LeadingJet_Central_Data_jet_nTracks': Hist(Regular(60, 0, 60, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=521779, variance=521779) (WeightedSum(value=522195, variance=522195) with flow),
#   '800_LeadingJet_Central_Data_jet_trackWidth': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=521765, variance=521765) (WeightedSum(value=522195, variance=522195) with flow),
#   '800_LeadingJet_Central_Data_jet_trackC1': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=521769, variance=521769) (WeightedSum(value=522195, variance=522195) with flow),
#   '800_LeadingJet_Central_Data_jet_trackBDT': Hist(Regular(100, -1, 1, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=522195, variance=522195),
#   '800_LeadingJet_Central_Data_GBDT_newScore': Hist(Regular(100, -5, 5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=522195, variance=522195),
#   '800_SubLeadingJet_Forward_Data_jet_pt': Hist(Regular(60, 500, 2000, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=263539, variance=263539),
#   '800_SubLeadingJet_Forward_Data_jet_eta': Hist(Regular(50, -2.5, 2.5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=263539, variance=263539),
#   '800_SubLeadingJet_Forward_Data_jet_nTracks': Hist(Regular(60, 0, 60, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=263244, variance=263244) (WeightedSum(value=263539, variance=263539) with flow),
#   '800_SubLeadingJet_Forward_Data_jet_trackWidth': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=263394, variance=263394) (WeightedSum(value=263539, variance=263539) with flow),
#   '800_SubLeadingJet_Forward_Data_jet_trackC1': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=263396, variance=263396) (WeightedSum(value=263539, variance=263539) with flow),
#   '800_SubLeadingJet_Forward_Data_jet_trackBDT': Hist(Regular(100, -1, 1, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=263539, variance=263539),
#   '800_SubLeadingJet_Forward_Data_GBDT_newScore': Hist(Regular(100, -5, 5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=263539, variance=263539),
#   '800_SubLeadingJet_Central_Data_jet_pt': Hist(Regular(60, 500, 2000, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=264921, variance=264921),
#   '800_SubLeadingJet_Central_Data_jet_eta': Hist(Regular(50, -2.5, 2.5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=264921, variance=264921),
#   '800_SubLeadingJet_Central_Data_jet_nTracks': Hist(Regular(60, 0, 60, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=264547, variance=264547) (WeightedSum(value=264921, variance=264921) with flow),
#   '800_SubLeadingJet_Central_Data_jet_trackWidth': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=264779, variance=264779) (WeightedSum(value=264921, variance=264921) with flow),
#   '800_SubLeadingJet_Central_Data_jet_trackC1': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=264779, variance=264779) (WeightedSum(value=264921, variance=264921) with flow),
#   '800_SubLeadingJet_Central_Data_jet_trackBDT': Hist(Regular(100, -1, 1, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=264921, variance=264921),
#   '800_SubLeadingJet_Central_Data_GBDT_newScore': Hist(Regular(100, -5, 5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=264921, variance=264921),
#   '1000_LeadingJet_Forward_Data_jet_pt': Hist(Regular(60, 500, 2000, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=124382, variance=124382),
#   '1000_LeadingJet_Forward_Data_jet_eta': Hist(Regular(50, -2.5, 2.5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=124382, variance=124382),
#   '1000_LeadingJet_Forward_Data_jet_nTracks': Hist(Regular(60, 0, 60, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=124193, variance=124193) (WeightedSum(value=124382, variance=124382) with flow),
#   '1000_LeadingJet_Forward_Data_jet_trackWidth': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=124214, variance=124214) (WeightedSum(value=124382, variance=124382) with flow),
#   '1000_LeadingJet_Forward_Data_jet_trackC1': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=124216, variance=124216) (WeightedSum(value=124382, variance=124382) with flow),
#   '1000_LeadingJet_Forward_Data_jet_trackBDT': Hist(Regular(100, -1, 1, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=124382, variance=124382),
#   '1000_LeadingJet_Forward_Data_GBDT_newScore': Hist(Regular(100, -5, 5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=124382, variance=124382),
#   '1000_LeadingJet_Central_Data_jet_pt': Hist(Regular(60, 500, 2000, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=123691, variance=123691),
#   '1000_LeadingJet_Central_Data_jet_eta': Hist(Regular(50, -2.5, 2.5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=123691, variance=123691),
#   '1000_LeadingJet_Central_Data_jet_nTracks': Hist(Regular(60, 0, 60, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=123405, variance=123405) (WeightedSum(value=123691, variance=123691) with flow),
#   '1000_LeadingJet_Central_Data_jet_trackWidth': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=123576, variance=123576) (WeightedSum(value=123691, variance=123691) with flow),
#   '1000_LeadingJet_Central_Data_jet_trackC1': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=123578, variance=123578) (WeightedSum(value=123691, variance=123691) with flow),
#   '1000_LeadingJet_Central_Data_jet_trackBDT': Hist(Regular(100, -1, 1, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=123691, variance=123691),
#   '1000_LeadingJet_Central_Data_GBDT_newScore': Hist(Regular(100, -5, 5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=123691, variance=123691),
#   '1000_SubLeadingJet_Forward_Data_jet_pt': Hist(Regular(60, 500, 2000, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=62324, variance=62324),
#   '1000_SubLeadingJet_Forward_Data_jet_eta': Hist(Regular(50, -2.5, 2.5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=62324, variance=62324),
#   '1000_SubLeadingJet_Forward_Data_jet_nTracks': Hist(Regular(60, 0, 60, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=62173, variance=62173) (WeightedSum(value=62324, variance=62324) with flow),
#   '1000_SubLeadingJet_Forward_Data_jet_trackWidth': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=62290, variance=62290) (WeightedSum(value=62324, variance=62324) with flow),
#   '1000_SubLeadingJet_Forward_Data_jet_trackC1': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=62292, variance=62292) (WeightedSum(value=62324, variance=62324) with flow),
#   '1000_SubLeadingJet_Forward_Data_jet_trackBDT': Hist(Regular(100, -1, 1, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=62324, variance=62324),
#   '1000_SubLeadingJet_Forward_Data_GBDT_newScore': Hist(Regular(100, -5, 5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=62324, variance=62324),
#   '1000_SubLeadingJet_Central_Data_jet_pt': Hist(Regular(60, 500, 2000, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=62207, variance=62207),
#   '1000_SubLeadingJet_Central_Data_jet_eta': Hist(Regular(50, -2.5, 2.5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=62207, variance=62207),
#   '1000_SubLeadingJet_Central_Data_jet_nTracks': Hist(Regular(60, 0, 60, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=62039, variance=62039) (WeightedSum(value=62207, variance=62207) with flow),
#   '1000_SubLeadingJet_Central_Data_jet_trackWidth': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=62163, variance=62163) (WeightedSum(value=62207, variance=62207) with flow),
#   '1000_SubLeadingJet_Central_Data_jet_trackC1': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=62163, variance=62163) (WeightedSum(value=62207, variance=62207) with flow),
#   '1000_SubLeadingJet_Central_Data_jet_trackBDT': Hist(Regular(100, -1, 1, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=62207, variance=62207),
#   '1000_SubLeadingJet_Central_Data_GBDT_newScore': Hist(Regular(100, -5, 5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=62207, variance=62207),
#   '1200_LeadingJet_Forward_Data_jet_pt': Hist(Regular(60, 500, 2000, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=41859, variance=41859),
#   '1200_LeadingJet_Forward_Data_jet_eta': Hist(Regular(50, -2.5, 2.5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=41859, variance=41859),
#   '1200_LeadingJet_Forward_Data_jet_nTracks': Hist(Regular(60, 0, 60, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=41726, variance=41726) (WeightedSum(value=41859, variance=41859) with flow),
#   '1200_LeadingJet_Forward_Data_jet_trackWidth': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=41811, variance=41811) (WeightedSum(value=41859, variance=41859) with flow),
#   '1200_LeadingJet_Forward_Data_jet_trackC1': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=41811, variance=41811) (WeightedSum(value=41859, variance=41859) with flow),
#   '1200_LeadingJet_Forward_Data_jet_trackBDT': Hist(Regular(100, -1, 1, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=41859, variance=41859),
#   '1200_LeadingJet_Forward_Data_GBDT_newScore': Hist(Regular(100, -5, 5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=41859, variance=41859),
#   '1200_LeadingJet_Central_Data_jet_pt': Hist(Regular(60, 500, 2000, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=42567, variance=42567),
#   '1200_LeadingJet_Central_Data_jet_eta': Hist(Regular(50, -2.5, 2.5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=42567, variance=42567),
#   '1200_LeadingJet_Central_Data_jet_nTracks': Hist(Regular(60, 0, 60, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=42402, variance=42402) (WeightedSum(value=42567, variance=42567) with flow),
#   '1200_LeadingJet_Central_Data_jet_trackWidth': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=42517, variance=42517) (WeightedSum(value=42567, variance=42567) with flow),
#   '1200_LeadingJet_Central_Data_jet_trackC1': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=42517, variance=42517) (WeightedSum(value=42567, variance=42567) with flow),
#   '1200_LeadingJet_Central_Data_jet_trackBDT': Hist(Regular(100, -1, 1, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=42567, variance=42567),
#   '1200_LeadingJet_Central_Data_GBDT_newScore': Hist(Regular(100, -5, 5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=42567, variance=42567),
#   '1200_SubLeadingJet_Forward_Data_jet_pt': Hist(Regular(60, 500, 2000, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=21050, variance=21050),
#   '1200_SubLeadingJet_Forward_Data_jet_eta': Hist(Regular(50, -2.5, 2.5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=21050, variance=21050),
#   '1200_SubLeadingJet_Forward_Data_jet_nTracks': Hist(Regular(60, 0, 60, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=20951, variance=20951) (WeightedSum(value=21050, variance=21050) with flow),
#   '1200_SubLeadingJet_Forward_Data_jet_trackWidth': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=21039, variance=21039) (WeightedSum(value=21050, variance=21050) with flow),
#   '1200_SubLeadingJet_Forward_Data_jet_trackC1': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=21039, variance=21039) (WeightedSum(value=21050, variance=21050) with flow),
#   '1200_SubLeadingJet_Forward_Data_jet_trackBDT': Hist(Regular(100, -1, 1, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=21050, variance=21050),
#   '1200_SubLeadingJet_Forward_Data_GBDT_newScore': Hist(Regular(100, -5, 5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=21050, variance=21050),
#   '1200_SubLeadingJet_Central_Data_jet_pt': Hist(Regular(60, 500, 2000, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=20860, variance=20860),
#   '1200_SubLeadingJet_Central_Data_jet_eta': Hist(Regular(50, -2.5, 2.5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=20860, variance=20860),
#   '1200_SubLeadingJet_Central_Data_jet_nTracks': Hist(Regular(60, 0, 60, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=20771, variance=20771) (WeightedSum(value=20860, variance=20860) with flow),
#   '1200_SubLeadingJet_Central_Data_jet_trackWidth': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=20846, variance=20846) (WeightedSum(value=20860, variance=20860) with flow),
#   '1200_SubLeadingJet_Central_Data_jet_trackC1': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=20846, variance=20846) (WeightedSum(value=20860, variance=20860) with flow),
#   '1200_SubLeadingJet_Central_Data_jet_trackBDT': Hist(Regular(100, -1, 1, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=20860, variance=20860),
#   '1200_SubLeadingJet_Central_Data_GBDT_newScore': Hist(Regular(100, -5, 5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=20860, variance=20860),
#   '1500_LeadingJet_Forward_Data_jet_pt': Hist(Regular(60, 500, 2000, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=9206, variance=9206),
#   '1500_LeadingJet_Forward_Data_jet_eta': Hist(Regular(50, -2.5, 2.5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=9206, variance=9206),
#   '1500_LeadingJet_Forward_Data_jet_nTracks': Hist(Regular(60, 0, 60, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=9165, variance=9165) (WeightedSum(value=9206, variance=9206) with flow),
#   '1500_LeadingJet_Forward_Data_jet_trackWidth': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=9199, variance=9199) (WeightedSum(value=9206, variance=9206) with flow),
#   '1500_LeadingJet_Forward_Data_jet_trackC1': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=9199, variance=9199) (WeightedSum(value=9206, variance=9206) with flow),
#   '1500_LeadingJet_Forward_Data_jet_trackBDT': Hist(Regular(100, -1, 1, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=9206, variance=9206),
#   '1500_LeadingJet_Forward_Data_GBDT_newScore': Hist(Regular(100, -5, 5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=9206, variance=9206),
#   '1500_LeadingJet_Central_Data_jet_pt': Hist(Regular(60, 500, 2000, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=9432, variance=9432),
#   '1500_LeadingJet_Central_Data_jet_eta': Hist(Regular(50, -2.5, 2.5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=9432, variance=9432),
#   '1500_LeadingJet_Central_Data_jet_nTracks': Hist(Regular(60, 0, 60, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=9369, variance=9369) (WeightedSum(value=9432, variance=9432) with flow),
#   '1500_LeadingJet_Central_Data_jet_trackWidth': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=9424, variance=9424) (WeightedSum(value=9432, variance=9432) with flow),
#   '1500_LeadingJet_Central_Data_jet_trackC1': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=9424, variance=9424) (WeightedSum(value=9432, variance=9432) with flow),
#   '1500_LeadingJet_Central_Data_jet_trackBDT': Hist(Regular(100, -1, 1, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=9432, variance=9432),
#   '1500_LeadingJet_Central_Data_GBDT_newScore': Hist(Regular(100, -5, 5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=9432, variance=9432),
#   '1500_SubLeadingJet_Forward_Data_jet_pt': Hist(Regular(60, 500, 2000, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=4163, variance=4163),
#   '1500_SubLeadingJet_Forward_Data_jet_eta': Hist(Regular(50, -2.5, 2.5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=4163, variance=4163),
#   '1500_SubLeadingJet_Forward_Data_jet_nTracks': Hist(Regular(60, 0, 60, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=4126, variance=4126) (WeightedSum(value=4163, variance=4163) with flow),
#   '1500_SubLeadingJet_Forward_Data_jet_trackWidth': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=4161, variance=4161) (WeightedSum(value=4163, variance=4163) with flow),
#   '1500_SubLeadingJet_Forward_Data_jet_trackC1': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=4161, variance=4161) (WeightedSum(value=4163, variance=4163) with flow),
#   '1500_SubLeadingJet_Forward_Data_jet_trackBDT': Hist(Regular(100, -1, 1, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=4163, variance=4163),
#   '1500_SubLeadingJet_Forward_Data_GBDT_newScore': Hist(Regular(100, -5, 5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=4163, variance=4163),
#   '1500_SubLeadingJet_Central_Data_jet_pt': Hist(Regular(60, 500, 2000, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=4078, variance=4078),
#   '1500_SubLeadingJet_Central_Data_jet_eta': Hist(Regular(50, -2.5, 2.5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=4078, variance=4078),
#   '1500_SubLeadingJet_Central_Data_jet_nTracks': Hist(Regular(60, 0, 60, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=4046, variance=4046) (WeightedSum(value=4078, variance=4078) with flow),
#   '1500_SubLeadingJet_Central_Data_jet_trackWidth': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=4073, variance=4073) (WeightedSum(value=4078, variance=4078) with flow),
#   '1500_SubLeadingJet_Central_Data_jet_trackC1': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=4073, variance=4073) (WeightedSum(value=4078, variance=4078) with flow),
#   '1500_SubLeadingJet_Central_Data_jet_trackBDT': Hist(Regular(100, -1, 1, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=4078, variance=4078),
#   '1500_SubLeadingJet_Central_Data_GBDT_newScore': Hist(Regular(100, -5, 5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=4078, variance=4078)},
#  'jet_nTracks_quark_reweighting_weights': {'500_LeadingJet_Forward_Data_jet_pt': Hist(Regular(60, 500, 2000, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=1.67437e+06, variance=1.67437e+06),
#   '500_LeadingJet_Forward_Data_jet_eta': Hist(Regular(50, -2.5, 2.5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=1.67437e+06, variance=1.67437e+06),
#   '500_LeadingJet_Forward_Data_jet_nTracks': Hist(Regular(60, 0, 60, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=1.67428e+06, variance=1.67428e+06) (WeightedSum(value=1.67437e+06, variance=1.67437e+06) with flow),
#   '500_LeadingJet_Forward_Data_jet_trackWidth': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=1.67307e+06, variance=1.67307e+06) (WeightedSum(value=1.67437e+06, variance=1.67437e+06) with flow),
#   '500_LeadingJet_Forward_Data_jet_trackC1': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=1.67308e+06, variance=1.67308e+06) (WeightedSum(value=1.67437e+06, variance=1.67437e+06) with flow),
#   '500_LeadingJet_Forward_Data_jet_trackBDT': Hist(Regular(100, -1, 1, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=1.67437e+06, variance=1.67437e+06),
#   '500_LeadingJet_Forward_Data_GBDT_newScore': Hist(Regular(100, -5, 5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=1.67437e+06, variance=1.67437e+06),
#   '500_LeadingJet_Central_Data_jet_pt': Hist(Regular(60, 500, 2000, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=1.7364e+06, variance=1.8751e+06),
#   '500_LeadingJet_Central_Data_jet_eta': Hist(Regular(50, -2.5, 2.5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=1.7364e+06, variance=1.8751e+06),
#   '500_LeadingJet_Central_Data_jet_nTracks': Hist(Regular(60, 0, 60, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=1.73629e+06, variance=1.875e+06) (WeightedSum(value=1.7364e+06, variance=1.8751e+06) with flow),
#   '500_LeadingJet_Central_Data_jet_trackWidth': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=1.7364e+06, variance=1.8751e+06),
#   '500_LeadingJet_Central_Data_jet_trackC1': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=1.7364e+06, variance=1.8751e+06),
#   '500_LeadingJet_Central_Data_jet_trackBDT': Hist(Regular(100, -1, 1, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=1.7364e+06, variance=1.8751e+06),
#   '500_LeadingJet_Central_Data_GBDT_newScore': Hist(Regular(100, -5, 5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=1.7364e+06, variance=1.8751e+06),
#   '500_SubLeadingJet_Forward_Data_jet_pt': Hist(Regular(60, 500, 2000, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=2.86582e+06, variance=2.86582e+06),
#   '500_SubLeadingJet_Forward_Data_jet_eta': Hist(Regular(50, -2.5, 2.5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=2.86582e+06, variance=2.86582e+06),
#   '500_SubLeadingJet_Forward_Data_jet_nTracks': Hist(Regular(60, 0, 60, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=2.86561e+06, variance=2.86561e+06) (WeightedSum(value=2.86582e+06, variance=2.86582e+06) with flow),
#   '500_SubLeadingJet_Forward_Data_jet_trackWidth': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=2.86442e+06, variance=2.86442e+06) (WeightedSum(value=2.86582e+06, variance=2.86582e+06) with flow),
#   '500_SubLeadingJet_Forward_Data_jet_trackC1': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=2.86443e+06, variance=2.86443e+06) (WeightedSum(value=2.86582e+06, variance=2.86582e+06) with flow),
#   '500_SubLeadingJet_Forward_Data_jet_trackBDT': Hist(Regular(100, -1, 1, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=2.86582e+06, variance=2.86582e+06),
#   '500_SubLeadingJet_Forward_Data_GBDT_newScore': Hist(Regular(100, -5, 5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=2.86582e+06, variance=2.86582e+06),
#   '500_SubLeadingJet_Central_Data_jet_pt': Hist(Regular(60, 500, 2000, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=3.21615e+06, variance=3.52264e+06),
#   '500_SubLeadingJet_Central_Data_jet_eta': Hist(Regular(50, -2.5, 2.5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=3.21615e+06, variance=3.52264e+06),
#   '500_SubLeadingJet_Central_Data_jet_nTracks': Hist(Regular(60, 0, 60, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=3.2159e+06, variance=3.52238e+06) (WeightedSum(value=3.21615e+06, variance=3.52264e+06) with flow),
#   '500_SubLeadingJet_Central_Data_jet_trackWidth': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=3.21615e+06, variance=3.52264e+06),
#   '500_SubLeadingJet_Central_Data_jet_trackC1': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=3.21615e+06, variance=3.52264e+06),
#   '500_SubLeadingJet_Central_Data_jet_trackBDT': Hist(Regular(100, -1, 1, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=3.21615e+06, variance=3.52264e+06),
#   '500_SubLeadingJet_Central_Data_GBDT_newScore': Hist(Regular(100, -5, 5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=3.21615e+06, variance=3.52264e+06),
#   '600_LeadingJet_Forward_Data_jet_pt': Hist(Regular(60, 500, 2000, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=2.41502e+06, variance=2.41502e+06),
#   '600_LeadingJet_Forward_Data_jet_eta': Hist(Regular(50, -2.5, 2.5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=2.41502e+06, variance=2.41502e+06),
#   '600_LeadingJet_Forward_Data_jet_nTracks': Hist(Regular(60, 0, 60, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=2.41455e+06, variance=2.41455e+06) (WeightedSum(value=2.41502e+06, variance=2.41502e+06) with flow),
#   '600_LeadingJet_Forward_Data_jet_trackWidth': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=2.41259e+06, variance=2.41259e+06) (WeightedSum(value=2.41502e+06, variance=2.41502e+06) with flow),
#   '600_LeadingJet_Forward_Data_jet_trackC1': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=2.41261e+06, variance=2.41261e+06) (WeightedSum(value=2.41502e+06, variance=2.41502e+06) with flow),
#   '600_LeadingJet_Forward_Data_jet_trackBDT': Hist(Regular(100, -1, 1, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=2.41502e+06, variance=2.41502e+06),
#   '600_LeadingJet_Forward_Data_GBDT_newScore': Hist(Regular(100, -5, 5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=2.41502e+06, variance=2.41502e+06),
#   '600_LeadingJet_Central_Data_jet_pt': Hist(Regular(60, 500, 2000, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=2.44726e+06, variance=2.61895e+06),
#   '600_LeadingJet_Central_Data_jet_eta': Hist(Regular(50, -2.5, 2.5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=2.44726e+06, variance=2.61895e+06),
#   '600_LeadingJet_Central_Data_jet_nTracks': Hist(Regular(60, 0, 60, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=2.44672e+06, variance=2.61841e+06) (WeightedSum(value=2.44726e+06, variance=2.61895e+06) with flow),
#   '600_LeadingJet_Central_Data_jet_trackWidth': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=2.44726e+06, variance=2.61895e+06),
#   '600_LeadingJet_Central_Data_jet_trackC1': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=2.44726e+06, variance=2.61895e+06),
#   '600_LeadingJet_Central_Data_jet_trackBDT': Hist(Regular(100, -1, 1, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=2.44726e+06, variance=2.61895e+06),
#   '600_LeadingJet_Central_Data_GBDT_newScore': Hist(Regular(100, -5, 5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=2.44726e+06, variance=2.61895e+06),
#   '600_SubLeadingJet_Forward_Data_jet_pt': Hist(Regular(60, 500, 2000, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=1.43213e+06, variance=1.43213e+06),
#   '600_SubLeadingJet_Forward_Data_jet_eta': Hist(Regular(50, -2.5, 2.5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=1.43213e+06, variance=1.43213e+06),
#   '600_SubLeadingJet_Forward_Data_jet_nTracks': Hist(Regular(60, 0, 60, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=1.43171e+06, variance=1.43171e+06) (WeightedSum(value=1.43213e+06, variance=1.43213e+06) with flow),
#   '600_SubLeadingJet_Forward_Data_jet_trackWidth': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=1.43131e+06, variance=1.43131e+06) (WeightedSum(value=1.43213e+06, variance=1.43213e+06) with flow),
#   '600_SubLeadingJet_Forward_Data_jet_trackC1': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=1.43132e+06, variance=1.43132e+06) (WeightedSum(value=1.43213e+06, variance=1.43213e+06) with flow),
#   '600_SubLeadingJet_Forward_Data_jet_trackBDT': Hist(Regular(100, -1, 1, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=1.43213e+06, variance=1.43213e+06),
#   '600_SubLeadingJet_Forward_Data_GBDT_newScore': Hist(Regular(100, -5, 5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=1.43213e+06, variance=1.43213e+06),
#   '600_SubLeadingJet_Central_Data_jet_pt': Hist(Regular(60, 500, 2000, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=1.57739e+06, variance=1.71618e+06),
#   '600_SubLeadingJet_Central_Data_jet_eta': Hist(Regular(50, -2.5, 2.5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=1.57739e+06, variance=1.71618e+06),
#   '600_SubLeadingJet_Central_Data_jet_nTracks': Hist(Regular(60, 0, 60, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=1.57684e+06, variance=1.71562e+06) (WeightedSum(value=1.57739e+06, variance=1.71618e+06) with flow),
#   '600_SubLeadingJet_Central_Data_jet_trackWidth': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=1.57739e+06, variance=1.71618e+06),
#   '600_SubLeadingJet_Central_Data_jet_trackC1': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=1.57739e+06, variance=1.71618e+06),
#   '600_SubLeadingJet_Central_Data_jet_trackBDT': Hist(Regular(100, -1, 1, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=1.57739e+06, variance=1.71618e+06),
#   '600_SubLeadingJet_Central_Data_GBDT_newScore': Hist(Regular(100, -5, 5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=1.57739e+06, variance=1.71618e+06),
#   '800_LeadingJet_Forward_Data_jet_pt': Hist(Regular(60, 500, 2000, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=532363, variance=532363),
#   '800_LeadingJet_Forward_Data_jet_eta': Hist(Regular(50, -2.5, 2.5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=532363, variance=532363),
#   '800_LeadingJet_Forward_Data_jet_nTracks': Hist(Regular(60, 0, 60, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=531973, variance=531973) (WeightedSum(value=532363, variance=532363) with flow),
#   '800_LeadingJet_Forward_Data_jet_trackWidth': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=531696, variance=531696) (WeightedSum(value=532363, variance=532363) with flow),
#   '800_LeadingJet_Forward_Data_jet_trackC1': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=531698, variance=531698) (WeightedSum(value=532363, variance=532363) with flow),
#   '800_LeadingJet_Forward_Data_jet_trackBDT': Hist(Regular(100, -1, 1, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=532363, variance=532363),
#   '800_LeadingJet_Forward_Data_GBDT_newScore': Hist(Regular(100, -5, 5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=532363, variance=532363),
#   '800_LeadingJet_Central_Data_jet_pt': Hist(Regular(60, 500, 2000, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=544378, variance=574145),
#   '800_LeadingJet_Central_Data_jet_eta': Hist(Regular(50, -2.5, 2.5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=544378, variance=574145),
#   '800_LeadingJet_Central_Data_jet_nTracks': Hist(Regular(60, 0, 60, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=543962, variance=573729) (WeightedSum(value=544378, variance=574145) with flow),
#   '800_LeadingJet_Central_Data_jet_trackWidth': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=544378, variance=574145),
#   '800_LeadingJet_Central_Data_jet_trackC1': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=544378, variance=574145),
#   '800_LeadingJet_Central_Data_jet_trackBDT': Hist(Regular(100, -1, 1, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=544378, variance=574145),
#   '800_LeadingJet_Central_Data_GBDT_newScore': Hist(Regular(100, -5, 5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=544378, variance=574145),
#   '800_SubLeadingJet_Forward_Data_jet_pt': Hist(Regular(60, 500, 2000, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=263539, variance=263539),
#   '800_SubLeadingJet_Forward_Data_jet_eta': Hist(Regular(50, -2.5, 2.5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=263539, variance=263539),
#   '800_SubLeadingJet_Forward_Data_jet_nTracks': Hist(Regular(60, 0, 60, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=263244, variance=263244) (WeightedSum(value=263539, variance=263539) with flow),
#   '800_SubLeadingJet_Forward_Data_jet_trackWidth': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=263394, variance=263394) (WeightedSum(value=263539, variance=263539) with flow),
#   '800_SubLeadingJet_Forward_Data_jet_trackC1': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=263396, variance=263396) (WeightedSum(value=263539, variance=263539) with flow),
#   '800_SubLeadingJet_Forward_Data_jet_trackBDT': Hist(Regular(100, -1, 1, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=263539, variance=263539),
#   '800_SubLeadingJet_Forward_Data_GBDT_newScore': Hist(Regular(100, -5, 5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=263539, variance=263539),
#   '800_SubLeadingJet_Central_Data_jet_pt': Hist(Regular(60, 500, 2000, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=280904, variance=300996),
#   '800_SubLeadingJet_Central_Data_jet_eta': Hist(Regular(50, -2.5, 2.5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=280904, variance=300996),
#   '800_SubLeadingJet_Central_Data_jet_nTracks': Hist(Regular(60, 0, 60, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=280530, variance=300622) (WeightedSum(value=280904, variance=300996) with flow),
#   '800_SubLeadingJet_Central_Data_jet_trackWidth': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=280904, variance=300996),
#   '800_SubLeadingJet_Central_Data_jet_trackC1': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=280904, variance=300996),
#   '800_SubLeadingJet_Central_Data_jet_trackBDT': Hist(Regular(100, -1, 1, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=280904, variance=300996),
#   '800_SubLeadingJet_Central_Data_GBDT_newScore': Hist(Regular(100, -5, 5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=280904, variance=300996),
#   '1000_LeadingJet_Forward_Data_jet_pt': Hist(Regular(60, 500, 2000, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=124382, variance=124382),
#   '1000_LeadingJet_Forward_Data_jet_eta': Hist(Regular(50, -2.5, 2.5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=124382, variance=124382),
#   '1000_LeadingJet_Forward_Data_jet_nTracks': Hist(Regular(60, 0, 60, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=124193, variance=124193) (WeightedSum(value=124382, variance=124382) with flow),
#   '1000_LeadingJet_Forward_Data_jet_trackWidth': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=124214, variance=124214) (WeightedSum(value=124382, variance=124382) with flow),
#   '1000_LeadingJet_Forward_Data_jet_trackC1': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=124216, variance=124216) (WeightedSum(value=124382, variance=124382) with flow),
#   '1000_LeadingJet_Forward_Data_jet_trackBDT': Hist(Regular(100, -1, 1, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=124382, variance=124382),
#   '1000_LeadingJet_Forward_Data_GBDT_newScore': Hist(Regular(100, -5, 5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=124382, variance=124382),
#   '1000_LeadingJet_Central_Data_jet_pt': Hist(Regular(60, 500, 2000, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=127247, variance=132007),
#   '1000_LeadingJet_Central_Data_jet_eta': Hist(Regular(50, -2.5, 2.5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=127247, variance=132007),
# ...
#   '800_SubLeadingJet_Central_Data_jet_trackC1': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=254573, variance=245959) (WeightedSum(value=254711, variance=246094) with flow),
#   '800_SubLeadingJet_Central_Data_jet_trackBDT': Hist(Regular(100, -1, 1, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=254711, variance=246094),
#   '800_SubLeadingJet_Central_Data_GBDT_newScore': Hist(Regular(100, -5, 5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=254711, variance=246094),
#   '1000_LeadingJet_Forward_Data_jet_pt': Hist(Regular(60, 500, 2000, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=124382, variance=124382),
#   '1000_LeadingJet_Forward_Data_jet_eta': Hist(Regular(50, -2.5, 2.5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=124382, variance=124382),
#   '1000_LeadingJet_Forward_Data_jet_nTracks': Hist(Regular(60, 0, 60, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=124193, variance=124193) (WeightedSum(value=124382, variance=124382) with flow),
#   '1000_LeadingJet_Forward_Data_jet_trackWidth': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=124214, variance=124214) (WeightedSum(value=124382, variance=124382) with flow),
#   '1000_LeadingJet_Forward_Data_jet_trackC1': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=124216, variance=124216) (WeightedSum(value=124382, variance=124382) with flow),
#   '1000_LeadingJet_Forward_Data_jet_trackBDT': Hist(Regular(100, -1, 1, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=124382, variance=124382),
#   '1000_LeadingJet_Forward_Data_GBDT_newScore': Hist(Regular(100, -5, 5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=124382, variance=124382),
#   '1000_LeadingJet_Central_Data_jet_pt': Hist(Regular(60, 500, 2000, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=119054, variance=115236),
#   '1000_LeadingJet_Central_Data_jet_eta': Hist(Regular(50, -2.5, 2.5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=119054, variance=115236),
#   '1000_LeadingJet_Central_Data_jet_nTracks': Hist(Regular(60, 0, 60, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=118736, variance=114883) (WeightedSum(value=119054, variance=115236) with flow),
#   '1000_LeadingJet_Central_Data_jet_trackWidth': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=118936, variance=115115) (WeightedSum(value=119054, variance=115236) with flow),
#   '1000_LeadingJet_Central_Data_jet_trackC1': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=118938, variance=115116) (WeightedSum(value=119054, variance=115236) with flow),
#   '1000_LeadingJet_Central_Data_jet_trackBDT': Hist(Regular(100, -1, 1, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=119054, variance=115236),
#   '1000_LeadingJet_Central_Data_GBDT_newScore': Hist(Regular(100, -5, 5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=119054, variance=115236),
#   '1000_SubLeadingJet_Forward_Data_jet_pt': Hist(Regular(60, 500, 2000, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=62324, variance=62324),
#   '1000_SubLeadingJet_Forward_Data_jet_eta': Hist(Regular(50, -2.5, 2.5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=62324, variance=62324),
#   '1000_SubLeadingJet_Forward_Data_jet_nTracks': Hist(Regular(60, 0, 60, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=62173, variance=62173) (WeightedSum(value=62324, variance=62324) with flow),
#   '1000_SubLeadingJet_Forward_Data_jet_trackWidth': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=62290, variance=62290) (WeightedSum(value=62324, variance=62324) with flow),
#   '1000_SubLeadingJet_Forward_Data_jet_trackC1': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=62292, variance=62292) (WeightedSum(value=62324, variance=62324) with flow),
#   '1000_SubLeadingJet_Forward_Data_jet_trackBDT': Hist(Regular(100, -1, 1, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=62324, variance=62324),
#   '1000_SubLeadingJet_Forward_Data_GBDT_newScore': Hist(Regular(100, -5, 5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=62324, variance=62324),
#   '1000_SubLeadingJet_Central_Data_jet_pt': Hist(Regular(60, 500, 2000, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=60225.5, variance=58616.3),
#   '1000_SubLeadingJet_Central_Data_jet_eta': Hist(Regular(50, -2.5, 2.5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=60225.5, variance=58616.3),
#   '1000_SubLeadingJet_Central_Data_jet_nTracks': Hist(Regular(60, 0, 60, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=60039, variance=58408.9) (WeightedSum(value=60225.5, variance=58616.3) with flow),
#   '1000_SubLeadingJet_Central_Data_jet_trackWidth': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=60180.2, variance=58569.6) (WeightedSum(value=60225.5, variance=58616.3) with flow),
#   '1000_SubLeadingJet_Central_Data_jet_trackC1': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=60180.2, variance=58569.6) (WeightedSum(value=60225.5, variance=58616.3) with flow),
#   '1000_SubLeadingJet_Central_Data_jet_trackBDT': Hist(Regular(100, -1, 1, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=60225.5, variance=58616.3),
#   '1000_SubLeadingJet_Central_Data_GBDT_newScore': Hist(Regular(100, -5, 5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=60225.5, variance=58616.3),
#   '1200_LeadingJet_Forward_Data_jet_pt': Hist(Regular(60, 500, 2000, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=41859, variance=41859),
#   '1200_LeadingJet_Forward_Data_jet_eta': Hist(Regular(50, -2.5, 2.5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=41859, variance=41859),
#   '1200_LeadingJet_Forward_Data_jet_nTracks': Hist(Regular(60, 0, 60, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=41726, variance=41726) (WeightedSum(value=41859, variance=41859) with flow),
#   '1200_LeadingJet_Forward_Data_jet_trackWidth': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=41811, variance=41811) (WeightedSum(value=41859, variance=41859) with flow),
#   '1200_LeadingJet_Forward_Data_jet_trackC1': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=41811, variance=41811) (WeightedSum(value=41859, variance=41859) with flow),
#   '1200_LeadingJet_Forward_Data_jet_trackBDT': Hist(Regular(100, -1, 1, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=41859, variance=41859),
#   '1200_LeadingJet_Forward_Data_GBDT_newScore': Hist(Regular(100, -5, 5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=41859, variance=41859),
#   '1200_LeadingJet_Central_Data_jet_pt': Hist(Regular(60, 500, 2000, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=40710, variance=39073.5),
#   '1200_LeadingJet_Central_Data_jet_eta': Hist(Regular(50, -2.5, 2.5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=40710, variance=39073.5),
#   '1200_LeadingJet_Central_Data_jet_nTracks': Hist(Regular(60, 0, 60, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=40528.1, variance=38872.9) (WeightedSum(value=40710, variance=39073.5) with flow),
#   '1200_LeadingJet_Central_Data_jet_trackWidth': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=40658.5, variance=39019.2) (WeightedSum(value=40710, variance=39073.5) with flow),
#   '1200_LeadingJet_Central_Data_jet_trackC1': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=40658.5, variance=39019.2) (WeightedSum(value=40710, variance=39073.5) with flow),
#   '1200_LeadingJet_Central_Data_jet_trackBDT': Hist(Regular(100, -1, 1, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=40710, variance=39073.5),
#   '1200_LeadingJet_Central_Data_GBDT_newScore': Hist(Regular(100, -5, 5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=40710, variance=39073.5),
#   '1200_SubLeadingJet_Forward_Data_jet_pt': Hist(Regular(60, 500, 2000, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=21050, variance=21050),
#   '1200_SubLeadingJet_Forward_Data_jet_eta': Hist(Regular(50, -2.5, 2.5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=21050, variance=21050),
#   '1200_SubLeadingJet_Forward_Data_jet_nTracks': Hist(Regular(60, 0, 60, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=20951, variance=20951) (WeightedSum(value=21050, variance=21050) with flow),
#   '1200_SubLeadingJet_Forward_Data_jet_trackWidth': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=21039, variance=21039) (WeightedSum(value=21050, variance=21050) with flow),
#   '1200_SubLeadingJet_Forward_Data_jet_trackC1': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=21039, variance=21039) (WeightedSum(value=21050, variance=21050) with flow),
#   '1200_SubLeadingJet_Forward_Data_jet_trackBDT': Hist(Regular(100, -1, 1, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=21050, variance=21050),
#   '1200_SubLeadingJet_Forward_Data_GBDT_newScore': Hist(Regular(100, -5, 5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=21050, variance=21050),
#   '1200_SubLeadingJet_Central_Data_jet_pt': Hist(Regular(60, 500, 2000, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=20074.5, variance=19388.6),
#   '1200_SubLeadingJet_Central_Data_jet_eta': Hist(Regular(50, -2.5, 2.5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=20074.5, variance=19388.6),
#   '1200_SubLeadingJet_Central_Data_jet_nTracks': Hist(Regular(60, 0, 60, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=19976.4, variance=19280.4) (WeightedSum(value=20074.5, variance=19388.6) with flow),
#   '1200_SubLeadingJet_Central_Data_jet_trackWidth': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=20061.7, variance=19376.8) (WeightedSum(value=20074.5, variance=19388.6) with flow),
#   '1200_SubLeadingJet_Central_Data_jet_trackC1': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=20061.7, variance=19376.8) (WeightedSum(value=20074.5, variance=19388.6) with flow),
#   '1200_SubLeadingJet_Central_Data_jet_trackBDT': Hist(Regular(100, -1, 1, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=20074.5, variance=19388.6),
#   '1200_SubLeadingJet_Central_Data_GBDT_newScore': Hist(Regular(100, -5, 5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=20074.5, variance=19388.6),
#   '1500_LeadingJet_Forward_Data_jet_pt': Hist(Regular(60, 500, 2000, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=9206, variance=9206),
#   '1500_LeadingJet_Forward_Data_jet_eta': Hist(Regular(50, -2.5, 2.5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=9206, variance=9206),
#   '1500_LeadingJet_Forward_Data_jet_nTracks': Hist(Regular(60, 0, 60, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=9165, variance=9165) (WeightedSum(value=9206, variance=9206) with flow),
#   '1500_LeadingJet_Forward_Data_jet_trackWidth': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=9199, variance=9199) (WeightedSum(value=9206, variance=9206) with flow),
#   '1500_LeadingJet_Forward_Data_jet_trackC1': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=9199, variance=9199) (WeightedSum(value=9206, variance=9206) with flow),
#   '1500_LeadingJet_Forward_Data_jet_trackBDT': Hist(Regular(100, -1, 1, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=9206, variance=9206),
#   '1500_LeadingJet_Forward_Data_GBDT_newScore': Hist(Regular(100, -5, 5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=9206, variance=9206),
#   '1500_LeadingJet_Central_Data_jet_pt': Hist(Regular(60, 500, 2000, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=9109.89, variance=8847.05),
#   '1500_LeadingJet_Central_Data_jet_eta': Hist(Regular(50, -2.5, 2.5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=9109.89, variance=8847.05),
#   '1500_LeadingJet_Central_Data_jet_nTracks': Hist(Regular(60, 0, 60, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=9041.64, variance=8773.1) (WeightedSum(value=9109.89, variance=8847.05) with flow),
#   '1500_LeadingJet_Central_Data_jet_trackWidth': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=9101.07, variance=8837.32) (WeightedSum(value=9109.89, variance=8847.05) with flow),
#   '1500_LeadingJet_Central_Data_jet_trackC1': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=9101.07, variance=8837.32) (WeightedSum(value=9109.89, variance=8847.05) with flow),
#   '1500_LeadingJet_Central_Data_jet_trackBDT': Hist(Regular(100, -1, 1, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=9109.89, variance=8847.05),
#   '1500_LeadingJet_Central_Data_GBDT_newScore': Hist(Regular(100, -5, 5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=9109.89, variance=8847.05),
#   '1500_SubLeadingJet_Forward_Data_jet_pt': Hist(Regular(60, 500, 2000, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=4163, variance=4163),
#   '1500_SubLeadingJet_Forward_Data_jet_eta': Hist(Regular(50, -2.5, 2.5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=4163, variance=4163),
#   '1500_SubLeadingJet_Forward_Data_jet_nTracks': Hist(Regular(60, 0, 60, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=4126, variance=4126) (WeightedSum(value=4163, variance=4163) with flow),
#   '1500_SubLeadingJet_Forward_Data_jet_trackWidth': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=4161, variance=4161) (WeightedSum(value=4163, variance=4163) with flow),
#   '1500_SubLeadingJet_Forward_Data_jet_trackC1': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=4161, variance=4161) (WeightedSum(value=4163, variance=4163) with flow),
#   '1500_SubLeadingJet_Forward_Data_jet_trackBDT': Hist(Regular(100, -1, 1, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=4163, variance=4163),
#   '1500_SubLeadingJet_Forward_Data_GBDT_newScore': Hist(Regular(100, -5, 5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=4163, variance=4163),
#   '1500_SubLeadingJet_Central_Data_jet_pt': Hist(Regular(60, 500, 2000, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=3955.1, variance=3856.53),
#   '1500_SubLeadingJet_Central_Data_jet_eta': Hist(Regular(50, -2.5, 2.5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=3955.1, variance=3856.53),
#   '1500_SubLeadingJet_Central_Data_jet_nTracks': Hist(Regular(60, 0, 60, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=3920.5, variance=3819.11) (WeightedSum(value=3955.1, variance=3856.53) with flow),
#   '1500_SubLeadingJet_Central_Data_jet_trackWidth': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=3949.54, variance=3850.35) (WeightedSum(value=3955.1, variance=3856.53) with flow),
#   '1500_SubLeadingJet_Central_Data_jet_trackC1': Hist(Regular(60, 0, 0.4, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=3949.54, variance=3850.35) (WeightedSum(value=3955.1, variance=3856.53) with flow),
#   '1500_SubLeadingJet_Central_Data_jet_trackBDT': Hist(Regular(100, -1, 1, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=3955.1, variance=3856.53),
#   '1500_SubLeadingJet_Central_Data_GBDT_newScore': Hist(Regular(100, -5, 5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=3955.1, variance=3856.53)}}

# %% [markdown]
# # Debug attach_reweight_factor for PythiaA

# %% [markdown]
# # Test merged hists

# %%
reweighted_hists_dicts = joblib.load('/global/cfs/projectdirs/atlas/hrzhao/HEP_Repo/QG_Calibration/NewWorkflow/test_slurm2/pythiaA_pred_hists.pkl')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [5], line 1
# ----> 1 reweighted_hists_dicts = joblib.load('/global/cfs/projectdirs/atlas/hrzhao/HEP_Repo/QG_Calibration/NewWorkflow/test_slurm2/pythiaA_pred_hists.pkl')
#
# File /global/cfs/cdirs/atlas/hrzhao/miniconda3/envs/ml/lib/python3.9/site-packages/joblib/numpy_pickle.py:658, in load(filename, mmap_mode)
#     652             if isinstance(fobj, str):
#     653                 # if the returned file object is a string, this means we
#     654                 # try to load a pickle file generated with an version of
#     655                 # Joblib so we load it with joblib compatibility function.
#     656                 return load_compatibility(fobj)
# --> 658             obj = _unpickle(fobj, filename, mmap_mode)
#     659 return obj
#
# File /global/cfs/cdirs/atlas/hrzhao/miniconda3/envs/ml/lib/python3.9/site-packages/joblib/numpy_pickle.py:577, in _unpickle(fobj, filename, mmap_mode)
#     575 obj = None
#     576 try:
# --> 577     obj = unpickler.load()
#     578     if unpickler.compat_mode:
#     579         warnings.warn("The file '%s' has been generated with a "
#     580                       "joblib version less than 0.10. "
#     581                       "Please regenerate this pickle file."
#     582                       % filename,
#     583                       DeprecationWarning, stacklevel=3)
#
# File /global/cfs/cdirs/atlas/hrzhao/miniconda3/envs/ml/lib/python3.9/pickle.py:1212, in _Unpickler.load(self)
#    1210             raise EOFError
#    1211         assert isinstance(key, bytes_types)
# -> 1212         dispatch[key[0]](self)
#    1213 except _Stop as stopinst:
#    1214     return stopinst.value
#
# File /global/cfs/cdirs/atlas/hrzhao/miniconda3/envs/ml/lib/python3.9/pickle.py:1537, in _Unpickler.load_stack_global(self)
#    1535 if type(name) is not str or type(module) is not str:
#    1536     raise UnpicklingError("STACK_GLOBAL requires str")
# -> 1537 self.append(self.find_class(module, name))
#
# File /global/cfs/cdirs/atlas/hrzhao/miniconda3/envs/ml/lib/python3.9/pickle.py:1581, in _Unpickler.find_class(self, module, name)
#    1579 __import__(module, level=0)
#    1580 if self.proto >= 4:
# -> 1581     return _getattribute(sys.modules[module], name)[0]
#    1582 else:
#    1583     return getattr(sys.modules[module], name)
#
# File /global/cfs/cdirs/atlas/hrzhao/miniconda3/envs/ml/lib/python3.9/pickle.py:331, in _getattribute(obj, name)
#     329         obj = getattr(obj, subpath)
#     330     except AttributeError:
# --> 331         raise AttributeError("Can't get attribute {!r} on {!r}"
#     332                              .format(name, obj)) from None
#     333 return obj, parent
#
# AttributeError: Can't get attribute 'merge_hists' on <module '__main__'>

# %%
reweighted_hists_dicts
# Out:
# {'event_weight': None,
#  'jet_nTracks_quark_reweighting_weights': None,
#  'jet_nTracks_gluon_reweighting_weights': None,
#  'jet_trackBDT_quark_reweighting_weights': None,
#  'jet_trackBDT_gluon_reweighting_weights': None,
#  'GBDT_newScore_quark_reweighting_weights': None,
#  'GBDT_newScore_gluon_reweighting_weights': None}
