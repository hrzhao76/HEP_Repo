# %%
import numpy as np 
import pandas as pd 
import hist
from hist import Hist

# %%
h1 = Hist.new.Reg(100, -10, 10).Weight()
h2 = Hist.new.Reg(100, -10, 10).Weight()

h_total = Hist.new.Reg(100, -10, 10, name="h_total").Weight()

# %%
sample1 = np.random.normal(1, 3, 1_000_000)
sample2 = np.random.normal(-5, 5, 1_000_000)

weight1 = np.random.normal(1, 3, 1_000_000)
weight2 = np.random.normal(1, 3, 1_000_000)

# %%
h1.fill(sample1)
h2.fill(sample2)
h1+h2
# Out:
# Hist(Regular(100, -10, 10, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=1.83848e+06, variance=1.83848e+06) (WeightedSum(value=2e+06, variance=2e+06) with flow)

# %%
def make_hist(values, bins, weights):
    # assuming bins numpy array with (start, stop, n_edges)
    _hist = Hist(hist.axis.Regular(bins=len(bins)-1, start=bins[0], stop=bins[-1], overflow=True, underflow=True), 
                                storage=hist.storage.Weight())
    _hist.fill(values, weight=weights)
    
    factor = np.sum(_hist.values())
    _normed_hist = _hist / (factor * _hist.axes[0].widths)

    return _hist, _normed_hist

# %%
bins = np.linspace(-10, 10, 101)
h1, h1_normed = make_hist(sample1, bins, weights=weight1)
h2, h2_normed = make_hist(sample2, bins, weights=weight2)

h_total, h_total_normaled = make_hist(np.concatenate((sample1, sample2)), bins, weights=np.concatenate(((weight1, weight2))))

# %%
# Out:
# Hist(Regular(100, -10, 10, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=1.83994e+06, variance=1.83845e+07) (WeightedSum(value=1.99858e+06, variance=1.99893e+07) with flow)

# %%
(h1_normed + h2_normed) / 2
# Out:
# Hist(Regular(100, -10, 10, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=5, variance=0.000136827) (WeightedSum(value=79325, variance=401203) with flow)

# %%
h_total_normaled
# Out:
# Hist(Regular(100, -10, 10, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=5, variance=0.000135765) (WeightedSum(value=158645, variance=1.60481e+06) with flow)

# %%
h1 + h2
# Out:
# Hist(Regular(100, -10, 10, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=1.83994e+06, variance=1.83845e+07) (WeightedSum(value=1.99858e+06, variance=1.99893e+07) with flow)

# %%
h_total
# Out:
# Hist(Regular(100, -10, 10, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=1.83994e+06, variance=1.83845e+07) (WeightedSum(value=1.99858e+06, variance=1.99893e+07) with flow)

# %%
h_addtion = h1 + h2
factor = np.sum(h_addtion.values())
h_addtion_normed = h_addtion / (factor * h_addtion.axes[0].widths)

# %%
h_addtion_normed
# Out:
# Hist(Regular(100, -10, 10, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=5, variance=0.000135765) (WeightedSum(value=158645, variance=1.60481e+06) with flow)

# %%
h_total_normaled
# Out:
# Hist(Regular(100, -10, 10, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=5, variance=0.000135765) (WeightedSum(value=158645, variance=1.60481e+06) with flow)
