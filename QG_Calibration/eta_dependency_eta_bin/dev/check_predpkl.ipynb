# %%
import joblib

# %%
pythiaA_pred_pkl_path = '/global/cfs/projectdirs/atlas/hrzhao/HEP_Repo/QG_Calibration/eta_dependency/nominal_eta_binned/nominal/pythiaA_pred.pkl'

# %%
pythiaA_pred_pkl = joblib.load(pythiaA_pred_pkl_path)

# %%
pythiaA_pred_pkl.head()
# Note the pt_idx should be change to eta_idx
# Out:
#         run       event      jet_pt   jet_eta  jet_nTracks  jet_trackWidth  \
# 0  364703.0  46193254.0  766.747925  1.298662          2.0        0.318292
# 1  364703.0  46193254.0  701.621765 -0.989431          2.0        0.269898
# 0  364704.0  46029800.0  567.369995  1.253171         34.0        0.157933
# 1  364704.0  46029800.0  517.005432 -0.372214         40.0        0.130906
# 2  364704.0  46032096.0  690.617371 -0.081755         14.0        0.023161
#
#    jet_trackC1  jet_trackBDT  jet_PartonTruthLabelID  event_weight  \
# 0     0.215923     -0.192873                    21.0     17.609434
# 1     0.157799     -0.126821                    -1.0     17.609434
# 0     0.323757      0.253368                    21.0      0.305107
# 1     0.308239      0.353442                    21.0      0.305107
# 2     0.134914     -0.209946                     3.0      0.449083
#
#    is_forward  is_leading  pt_idx target  GBDT_newScore
# ...

# %%
pythiaA_pred_pkl['jet_eta'].min()
# Out:
# -2.0999996662139893

# %%
pythiaA_pred_hists_path = '/global/cfs/projectdirs/atlas/hrzhao/HEP_Repo/QG_Calibration/eta_dependency/nominal_eta_binned/nominal/pythiaA_pred_hists.pkl'

# %%
pythiaA_pred_hists = joblib.load(pythiaA_pred_hists_path)

# %%
pythiaA_pred_hists['event_weight']['1.5_LeadingJet_Forward_Gluon_jet_eta']
# Out:
# Hist(Regular(50, -2.5, 2.5, label='Axis 0'), storage=Weight()) # Sum: WeightedSum(value=343106, variance=274087)

# %%
none_Extraction_Results = joblib.load('/global/cfs/projectdirs/atlas/hrzhao/HEP_Repo/QG_Calibration/eta_dependency/nominal_eta_binned/nominal/nominal/plots/ADE/Extraction_Results/none_Extraction_Results.pkl')

# %%
none_Extraction_Results['jet_nTracks'][0].keys()
# Out:
# dict_keys(['Forward_MC', 'Central_MC', 'Forward_Data', 'Central_Data', 'Quark', 'Gluon', 'Forward_Quark', 'Central_Quark', 'Forward_Gluon', 'Central_Gluon', 'f', 'f_inv', 'p_Quark', 'p_Gluon', 'p_Forward_Quark', 'p_Central_Quark', 'p_Forward_Gluon', 'p_Central_Gluon', 'extract_p_Quark_MC', 'extract_p_Gluon_MC', 'extract_p_Quark_Data', 'extract_p_Gluon_Data'])

# %%
none_Extraction_Results['jet_nTracks'][1.5]['extract_p_Quark_Data']
# Out:
# array([0.0+/-0, 0.0+/-0, 0.000592653467322098+/-0.00012101534803159178,
#        0.0009579574519038422+/-0.00017493405281346157,
#        0.0032509668283334965+/-0.00024074523925966476,
#        0.006896546682719468+/-0.00033516881149117775,
#        0.012427024319166306+/-0.00044086273794581403,
#        0.01997491613142944+/-0.000546349858375403,
#        0.02759965829892408+/-0.0006513600358209693,
#        0.03681729657120904+/-0.0007334374909430493,
#        0.04682316465043487+/-0.0007969931960118979,
#        0.054543474854779825+/-0.0008485385333750262,
#        0.06047654573146055+/-0.0008789245880568967,
#        0.06151578022682064+/-0.0009068261318929273,
#        0.06320411911247971+/-0.0009142687350467116,
#        0.06205853128882752+/-0.0009150689936939768,
#        0.056894841365679044+/-0.0009183746703539683,
#        0.05687953350455731+/-0.0008989251248741507,
#        0.0524175961689764+/-0.000884453065234866,
# ...

# %%
none_Extraction_Results['jet_nTracks'][1.5]['extract_p_Quark_Data']
# Out:
# array([0.0+/-0, 0.0+/-0, 0.000592653467322098+/-0.00012101534803159178,
#        0.0009579574519038422+/-0.00017493405281346157,
#        0.0032509668283334965+/-0.00024074523925966476,
#        0.006896546682719468+/-0.00033516881149117775,
#        0.012427024319166306+/-0.00044086273794581403,
#        0.01997491613142944+/-0.000546349858375403,
#        0.02759965829892408+/-0.0006513600358209693,
#        0.03681729657120904+/-0.0007334374909430493,
#        0.04682316465043487+/-0.0007969931960118979,
#        0.054543474854779825+/-0.0008485385333750262,
#        0.06047654573146055+/-0.0008789245880568967,
#        0.06151578022682064+/-0.0009068261318929273,
#        0.06320411911247971+/-0.0009142687350467116,
#        0.06205853128882752+/-0.0009150689936939768,
#        0.056894841365679044+/-0.0009183746703539683,
#        0.05687953350455731+/-0.0008989251248741507,
#        0.0524175961689764+/-0.000884453065234866,
# ...
